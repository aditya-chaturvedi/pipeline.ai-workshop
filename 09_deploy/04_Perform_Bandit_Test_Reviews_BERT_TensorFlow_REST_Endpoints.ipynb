# %% [markdown]
# # Multi-Armed Bandits and Reinforcement Learning with Amazon SageMaker
#
# We demonstrate how you can manage your own contextual multi-armed bandit workflow on SageMaker using the built-in [AWS Reinforcement Learning Container](https://github.com/aws/sagemaker-rl-container) container to train and deploy contextual bandit models. We show how to train these models that interact with a live environment (using a simulated client application) and continuously update the model with efficient exploration.
#
# ### Why Contextual Bandits?
#
# Wherever we look to personalize content for a user (content layout, ads, search, product recommendations, etc.), contextual bandits come in handy. Traditional personalization methods collect a training dataset, build a model and deploy it for generating recommendations. However, the training algorithm does not inform us on how to collect this dataset, especially in a production system where generating poor recommendations lead to loss of revenue. Contextual bandit algorithms help us collect this data in a strategic manner by trading off between exploiting known information and exploring recommendations which may yield higher benefits. The collected data is used to update the personalization model in an online manner. Therefore, contextual bandits help us train a personalization model while minimizing the impact of poor recommendations.

# %% [markdown]
# ![](img/multi_armed_bandit_maximize_reward.png)

# %% [markdown]
# To implement the exploration-exploitation strategy, we need an iterative training and deployment system that: (1) recommends an action using the contextual bandit model based on user context, (2) captures the implicit feedback over time and (3) continuously trains the model with incremental interaction data. In this notebook, we show how to setup the infrastructure needed for such an iterative learning system. While the example demonstrates a bandits application, these continual learning systems are useful more generally in dynamic scenarios where models need to be continually updated to capture the recent trends in the data (e.g. tracking fraud behaviors based on detection mechanisms or tracking user interests over time).
#
# In a typical supervised learning setup, the model is trained with a SageMaker training job and it is hosted behind a SageMaker hosting endpoint. The client application calls the endpoint for inference and receives a response. In bandits, the client application also sends the reward (a score assigned to each recommendation generated by the model) back for subsequent model training. These rewards will be part of the dataset for the subsequent model training.

# %% [markdown]
# # Relevant Links
#
# In-Practice
# * [AWS Blog Post on Contextual Multi-Armed Bandits](https://aws.amazon.com/blogs/machine-learning/power-contextual-bandits-using-continual-learning-with-amazon-sagemaker-rl/)
# * [Multi-Armed Bandits at StitchFix](https://multithreaded.stitchfix.com/blog/2020/08/05/bandits/)
# * [Introduction to Contextual Bandits](https://getstream.io/blog/introduction-contextual-bandits/)
# * [Vowpal Wabbit Contextual Bandit Algorithms](https://github.com/VowpalWabbit/vowpal_wabbit/wiki/Contextual-Bandit-algorithms)
#
# Theory
# * [Learning to Interact](https://hunch.net/~jl/interact.pdf)
# * [Contextual Bandit Bake-Off](https://arxiv.org/pdf/1802.04064.pdf)
# * [Doubly-Robust Policy Evaluation and Learning](https://arxiv.org/pdf/1103.4601.pdf)
#
# Code
# * [AWS Open Source Reinforcement Learning Containers](https://github.com/aws/sagemaker-rl-container)
# * [AWS Open Source Bandit Experiment Manager](./common/sagemaker_rl/orchestrator/workflow/manager)
# * [Vowpal Wabbit Reinforcement Learning Framework](https://github.com/VowpalWabbit/)

# %% [markdown]
# # AWS Open Source Bandit `ExperimentManager` Library

# %% [markdown]
# ![](img/multi_armed_bandit_traffic_shift.png)

# %% [markdown]
# The bandit model is implemented by the open source [**Bandit Experiment Manager**](./common/sagemaker_rl/orchestrator/workflow/manager/) provided with this example.  This This implementation continuously updates a Vowpal Wabbit reinforcement learning model using Amazon SageMaker, DynamoDB, Kinesis, and S3.
#
# The client application, a recommender system with a review service in our case, pings the SageMaker hosting endpoint that is serving the bandit model.  The application sends the an `event` with the `context` (ie. user, product, and review text) to the bandit model and receives a recommended action from the bandit model.  In our case, the action is 1 of 2 BERT models that we are testing.  The bandit model stores this event data (given context and recommended action) in S3 using Amazon Kinesis.  _Note:  The context makes this a "contextual bandit" and differentiates this implementation from a regular multi-armed bandit._
#
# The client application uses the recommended BERT model to classify the review text as star rating 1 through 5 and  compares the predicted star rating to the user-selected star rating.  If the BERT model correctly predicts the star rating of the review text (ie. matches the user-selected star rating), then the bandit model is rewarded with `reward=1`.  If the BERT model incorrectly classifies the star rating of the review text, the bandit model is not rewarded (`reward=0`).
#
# The client application stores the rewards data in S3 using Amazon Kinesis.  Periodically (ie. every 100 rewards), we incrementally train an updated bandit model with the latest the reward and event data.  This updated bandit model is evaluated against the current model using a holdout dataset of rewards and events.  If the bandit model accuracy is above a given threshold relative to the existing model, it is automatically deployed in a blue/green manner with no downtime.  SageMaker RL supports offline evaluation by performing counterfactual analysis (CFA).  By default, we apply [**doubly robust (DR) estimation**](https://arxiv.org/pdf/1103.4601.pdf) method. The bandit model tries to minimize the cost (`1 - reward`), so a smaller evaluation score indicates better bandit model performance.
#
# Unlike traditional A/B tests, the bandit model will learn the best BERT model (action) for a given context over time and begin to shift traffic to the best model.  Depending on the aggressiveness of the bandit model algorithm selected, the bandit model will continuously explore the under-performing models, but start to favor and exploit the over-performing models.  And unlike A/B tests, multi-armed bandits allow you to add a new action (ie. BERT model) dynamically throughout the life of the experiment.  When the bandit model sees the new BERT model, it will start sending traffic and exploring the accuracy of the new BERT model - alongside the existing BERT models in the experiment.
#
# #### Local Mode
#
# To facilitate experimentation, we provide a `local_mode` that runs the contextual bandit example using the SageMaker Notebook instance itself instead of the SageMaker training and hosting cluster instances.  The workflow remains the same in `local_mode`, but runs much faster for small datasets.  Hence, it is a useful tool for experimenting and debugging.  However, it will not scale to production use cases with high throughput and large datasets.  In `local_mode`, the training, evaluation, and hosting is done in the local [SageMaker Vowpal Wabbit Docker Container](https://github.com/aws/sagemaker-rl-container).

# %%
import boto3
import sagemaker
import pandas as pd

sess   = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name='sagemaker', region_name=region)

# %%
# %store -r tensorflow_endpoint_name

# %%
try:
    tensorflow_endpoint_name
    print('[OK]')
except NameError:
    print('+++++++++++++++++++++++++++++++')
    print('[ERROR] Please run the notebooks in this section before you continue.')
    print('+++++++++++++++++++++++++++++++')
# Out:
# [OK]

# %%
print(tensorflow_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-05-088-tf-1601151470

# %%
# %store -r pytorch_endpoint_name

# %%
try:
    pytorch_endpoint_name
    print('[OK]')    
except NameError:
    print('+++++++++++++++++++++++++++++++')
    print('[ERROR] Please run the notebooks in this section before you continue.')
    print('+++++++++++++++++++++++++++++++')
# Out:
# [OK]

# %%
print(pytorch_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-05-088-pt-1601151131

# %% [markdown]
# # Configure the 2 BERT Models to Test with our Bandit Experiment

# %% [markdown]
# Now that the last trained bandit model is deployed as a SageMaker Endpoint, the client application will send the context to the endpoint and receive the recommended action.  The bandit model will recommend 1 of 2 actions in our example:  `1` or `2` which correspond to BERT model 1 and BERT model 2, respectively.  Let's configure these 2 BERT models below.

# %%
model_1_endpoint_name = tensorflow_endpoint_name

# %%
print(model_1_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-05-088-tf-1601151470

# %%
try:
    waiter = sm.get_waiter('endpoint_in_service')
    waiter.wait(EndpointName=model_1_endpoint_name)
except:
    print('###################')
    print('The endpoint is not running.')
    print('Please re-run the previous section to deploy the endpoint.')
    print('###################')

# %%
import json
from sagemaker.tensorflow.model import TensorFlowPredictor

model1 = TensorFlowPredictor(endpoint_name=model_1_endpoint_name,
                             sagemaker_session=sess,
                             model_name='saved_model',
                             model_version=0)

# %%
review = 'This is great!'

model1_predicted_class = model1.predict(review)[0]

print('[Predicted Star Rating: {}]'.format(model1_predicted_class), review)
# Out:
# [Predicted Star Rating: 5] This is great!

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/endpoints/{}">Model 1 SageMaker REST Endpoint</a></b>'.format(region, model_1_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-west-2#/endpoints/tensorflow-training-2020-09-26-18-45-05-088-tf-1601151470">Model 1 SageMaker REST Endpoint</a></b>

# %%
model_2_endpoint_name = pytorch_endpoint_name

# %%
print(model_2_endpoint_name)
# Out:
# tensorflow-training-2020-09-26-18-45-05-088-pt-1601151131

# %%
try:
    waiter = sm.get_waiter('endpoint_in_service')
    waiter.wait(EndpointName=model_2_endpoint_name)
except:
    print('###################')
    print('The endpoint is not running.')
    print('Please re-run the previous section to deploy the endpoint.')
    print('###################')

# %%
import json
from sagemaker.predictor import Predictor

model2 = Predictor(endpoint_name=model_2_endpoint_name,
                   sagemaker_session=sess)

# %%
review = 'This is great!'

model2_predicted_class = model2.predict(review).decode('utf-8')

print('[Predicted Star Rating: {}]'.format(model2_predicted_class), review)
# Out:
# [Predicted Star Rating: 5] This is great!

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region={}#/endpoints/{}">Model 2 SageMaker REST Endpoint</a></b>'.format(region, model_2_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/sagemaker/home?region=us-west-2#/endpoints/tensorflow-training-2020-09-26-18-45-05-088-pt-1601151131">Model 2 SageMaker REST Endpoint</a></b>

# %%
import yaml
import sys
import numpy as np
import time
import sagemaker

sys.path.append('common')
sys.path.append('common/sagemaker_rl')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ### Configuration
#
# The configuration for the bandits application can be specified in a `config.yaml` file as can be seen below. It configures the AWS resources needed. The DynamoDB tables are used to store metadata related to experiments, models and data joins. The `private_resource` specifices the SageMaker instance types and counts used for training, evaluation and hosting. The SageMaker container image is used for the bandits application. This config file also contains algorithm and SageMaker-specific setups.  Note that all the data generated and used for the bandits application will be stored in `s3://sagemaker-{REGION}-{AWS_ACCOUNT_ID}/{experiment_id}/`.
#
# Please make sure that the `num_arms` parameter in the config is equal to the number of actions in the client application (which is defined in the cell below).
#
# The Docker image is defined here:  https://github.com/aws/sagemaker-rl-container/blob/master/vw/docker/8.7.0/Dockerfile

# %%
# !pygmentize 'config.yaml'
# Out:
# resource:
#   shared_resource:
#     resources_cf_stack_name: "BanditsSharedResourceStack" # cloud formation stack
#     experiment_db:
#       table_name: "BanditsExperimentTable" # Dynamo table for status of an experiment
#     model_db:
#       table_name: "BanditsModelTable" # Dynamo table for status of all models trained
#     join_db:
#       table_name: "BanditsJoinTable" # Dynamo table for status of all joining job for reward ingestion
#     iam_role:
#       role_name: "BanditsIAMRole"
#   private_resource:
#     hosting_fleet:
#       instance_type: "ml.t2.medium"
#       instance_count: 1
#     training_fleet:
#       instance_type: "ml.c5.4xlarge"
#     evaluation_fleet:
#       instance_type: "ml.c5.4xlarge"
# image: "462105765813.dkr.ecr.{AWS_REGION}.amazonaws.com/sagemaker-rl-vw-container:vw-8.7.0-cpu" # Vowpal Wabbit container
# algor: # Vowpal Wabbit algorithm parameters
#   algorithms_parameters:
#     exploration_policy: "cover" # supports "egreedy", "bag", "cover"
#     epsilon: 0.10 # percent to explore with egreedy exploration policy
#     num_policies: 3 # number of nested policies to create when using bag or cover exploration policy
#     num_arms: 2
#     cfa_type: "dr" # supports "dr", "ips"
# local_mode: true # use local mode?
# soft_deployment: true # use the same endpoint with updated model using a blue-green deployment?

# %%
config_file = 'config.yaml'
with open(config_file, 'r') as yaml_file:
    config = yaml.load(yaml_file, Loader=yaml.FullLoader)

# %% [markdown]
# # Additional permissions for the IAM role
# IAM role requires additional permissions for [AWS CloudFormation](https://aws.amazon.com/cloudformation/), [Amazon DynamoDB](https://aws.amazon.com/dynamodb/), [Amazon Kinesis Data Firehose](https://aws.amazon.com/kinesis/data-firehose/) and [Amazon Athena](https://aws.amazon.com/athena/). Make sure the SageMaker role you are using has the permissions.

# %%
# from markdown_helper import *
# from IPython.display import Markdown

# display(Markdown(generate_help_for_experiment_manager_permissions(role)))

# %% [markdown]
# ### Client Application (Environment)
# The client application simulates a live environment that uses the bandit model to recommend a BERT model to classify review text submitted by the application user.
#
# The logic of reward generation resides in the client application.  We simulate the online learning loop with feedback.  The data consists of 2 actions - 1 for each BERT model under test.  If the bandit model selects the right class, then the model is rewarded with `reward=1`.  Otherwise, the bandit model receives `reward=0`.
#
# The workflow of the client application is as follows:
# - Our client application picks sample review text at random, which is sent to the bandit model (SageMaker endpoint) to recommend an action (BERT model) to classify the review text into star rating 1 through 5.
# - The bandit model returns an action, an action probability, and an `event_id` for this prediction event.
# - Since the client application uses the Amazon Customer Reviews Dataset, we know the true star rating for the review text
# - The client application compares the predicted and true star rating and assigns a reward to the bandit model using Amazon Kinesis, S3, and DynamoDB.  (The `event_id` is used to join the event and reward data.)
#
# `event_id` is a unique identifier for each interaction. It is used to join inference data `<state, action, action_probability>` with the reward data.
#
# In a later cell of this notebook, we illustrate how the client application interacts with the bandit model endpoint and receives the recommended action (BERT model).

# %% [markdown]
# ### Step-by-step bandits model development
#
# [**Bandit Experiment Manager**](./common/sagemaker_rl/orchestrator/workflow/manager/) is the top level class for all the Bandits/RL and continual learning workflows. Similar to the estimators in the [Sagemaker Python SDK](https://github.com/aws/sagemaker-python-sdk), `ExperimentManager` contains methods for training, deployment and evaluation. It keeps track of the job status and reflects current progress in the workflow.
#
# Start the application using the `ExperimentManager` class

# %%
import time
timestamp = int(time.time())

experiment_name = 'bandits-{}'.format(timestamp)

# %% [markdown]
# # `ExperimentManager` will create a AWS CloudFormation Stack of additional resources needed for the Bandit experiment.

# %%
from orchestrator.workflow.manager.experiment_manager import ExperimentManager

bandit_experiment_manager = ExperimentManager(config, experiment_id=experiment_name)
# Out:
# INFO:orchestrator.resource_manager:Creating a new CloudFormation stack for Shared Resources. You can always reuse this StackName in your other experiments
# INFO:orchestrator.resource_manager:[
#     {
#         "ParameterKey": "IAMRoleName",
#         "ParameterValue": "BanditsIAMRole",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ExperimentDbName",
#         "ParameterValue": "BanditsExperimentTable",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ExperimentDbRCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ExperimentDbWCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ModelDbName",
#         "ParameterValue": "BanditsModelTable",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ModelDbRCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "ModelDbWCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "JoinDbName",
#         "ParameterValue": "BanditsJoinTable",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "JoinDbRCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     },
#     {
#         "ParameterKey": "JoinDbWCU",
#         "ParameterValue": "5",
#         "UsePreviousValue": true,
#         "ResolvedValue": "string"
#     }
# ]
# INFO:orchestrator.resource_manager:Creating CloudFormation Stack for shared resource!
# INFO:orchestrator.resource_manager:Waiting for stack to get to CREATE_COMPLETE state....

# %%
try:
    bandit_experiment_manager.clean_resource(experiment_id=bandit_experiment_manager.experiment_id)
    bandit_experiment_manager.clean_table_records(experiment_id=bandit_experiment_manager.experiment_id)
except:
    print('Ignore any errors.  Errors are OK.')
# Out:
# INFO:orchestrator:Deleting hosting endpoint 'bandits-1601151981'...
# WARNING:orchestrator.clients.ddb.experiment_db_client:Deleting experiment record...

# %%
bandit_experiment_manager = ExperimentManager(config, experiment_id=experiment_name)
# Out:
# INFO:orchestrator.resource_manager:Using Resources in CloudFormation stack named: BanditsSharedResourceStack for Shared Resources.

# %% [markdown]
# # Initialize the Bandit Model
# To start a new experiment, we need to initialize the first bandit model or "policy" in reinforcement learning terminology.
#
# If we have historical data in the format `(state, action, action probability, reward)`, we can perform a "warm start" and learn the bandit model offline.
#
# However, let's assume we are starting with no historical data and initialize a random bandit model using `initialize_first_model()`.

# %%
bandit_experiment_manager.initialize_first_model()
# Out:
# INFO:orchestrator:Next Model name would be bandits-1601151981-model-id-1601152031
# INFO:orchestrator:Start training job for model 'bandits-1601151981-model-id-1601152031''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpbdttp7nx_algo-1-v8ui6_1 ...
# Attaching to tmpbdttp7nx_algo-1-v8ui6_12mdone
# algo-1-v8ui6_1  | 2020-09-26 20:27:37,907 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-v8ui6_1  | 2020-09-26 20:27:37,919 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-v8ui6_1  | 2020-09-26 20:27:37,930 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-v8ui6_1  | 2020-09-26 20:27:37,939 sagemaker-containers INFO     Invoking user script
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  | Training Env:
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  | {
# algo-1-v8ui6_1  |     "additional_framework_parameters": {
# algo-1-v8ui6_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-v8ui6_1  |     },
# algo-1-v8ui6_1  |     "channel_input_dirs": {},
# algo-1-v8ui6_1  |     "current_host": "algo-1-v8ui6",
# algo-1-v8ui6_1  |     "framework_module": null,
# algo-1-v8ui6_1  |     "hosts": [
# algo-1-v8ui6_1  |         "algo-1-v8ui6"
# algo-1-v8ui6_1  |     ],
# algo-1-v8ui6_1  |     "hyperparameters": {
# algo-1-v8ui6_1  |         "exploration_policy": "cover",
# algo-1-v8ui6_1  |         "epsilon": 0.1,
# algo-1-v8ui6_1  |         "num_policies": 3,
# algo-1-v8ui6_1  |         "num_arms": 2,
# algo-1-v8ui6_1  |         "cfa_type": "dr"
# algo-1-v8ui6_1  |     },
# algo-1-v8ui6_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-v8ui6_1  |     "input_data_config": {},
# algo-1-v8ui6_1  |     "input_dir": "/opt/ml/input",
# algo-1-v8ui6_1  |     "is_master": true,
# algo-1-v8ui6_1  |     "job_name": "bandits-1601151981-model-id-1601152031",
# algo-1-v8ui6_1  |     "log_level": 20,
# algo-1-v8ui6_1  |     "master_hostname": "algo-1-v8ui6",
# algo-1-v8ui6_1  |     "model_dir": "/opt/ml/model",
# algo-1-v8ui6_1  |     "module_dir": "s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152031/source/sourcedir.tar.gz",
# algo-1-v8ui6_1  |     "module_name": "train-vw",
# algo-1-v8ui6_1  |     "network_interface_name": "eth0",
# algo-1-v8ui6_1  |     "num_cpus": 8,
# algo-1-v8ui6_1  |     "num_gpus": 0,
# algo-1-v8ui6_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-v8ui6_1  |     "output_dir": "/opt/ml/output",
# algo-1-v8ui6_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-v8ui6_1  |     "resource_config": {
# algo-1-v8ui6_1  |         "current_host": "algo-1-v8ui6",
# algo-1-v8ui6_1  |         "hosts": [
# algo-1-v8ui6_1  |             "algo-1-v8ui6"
# algo-1-v8ui6_1  |         ]
# algo-1-v8ui6_1  |     },
# algo-1-v8ui6_1  |     "user_entry_point": "train-vw.py"
# algo-1-v8ui6_1  | }
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  | Environment variables:
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  | SM_HOSTS=["algo-1-v8ui6"]
# algo-1-v8ui6_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-v8ui6_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-v8ui6_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-v8ui6_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-v8ui6_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-v8ui6","hosts":["algo-1-v8ui6"]}
# algo-1-v8ui6_1  | SM_INPUT_DATA_CONFIG={}
# algo-1-v8ui6_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-v8ui6_1  | SM_CHANNELS=[]
# algo-1-v8ui6_1  | SM_CURRENT_HOST=algo-1-v8ui6
# algo-1-v8ui6_1  | SM_MODULE_NAME=train-vw
# algo-1-v8ui6_1  | SM_LOG_LEVEL=20
# algo-1-v8ui6_1  | SM_FRAMEWORK_MODULE=
# algo-1-v8ui6_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-v8ui6_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-v8ui6_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-v8ui6_1  | SM_NUM_CPUS=8
# algo-1-v8ui6_1  | SM_NUM_GPUS=0
# algo-1-v8ui6_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-v8ui6_1  | SM_MODULE_DIR=s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152031/source/sourcedir.tar.gz
# algo-1-v8ui6_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1-v8ui6","framework_module":null,"hosts":["algo-1-v8ui6"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601151981-model-id-1601152031","log_level":20,"master_hostname":"algo-1-v8ui6","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152031/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-v8ui6","hosts":["algo-1-v8ui6"]},"user_entry_point":"train-vw.py"}
# algo-1-v8ui6_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-v8ui6_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-v8ui6_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-v8ui6_1  | SM_HP_EPSILON=0.1
# algo-1-v8ui6_1  | SM_HP_NUM_POLICIES=3
# algo-1-v8ui6_1  | SM_HP_NUM_ARMS=2
# algo-1-v8ui6_1  | SM_HP_CFA_TYPE=dr
# algo-1-v8ui6_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  | Invoking script with the following command:
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  |
# algo-1-v8ui6_1  | INFO:root:channels []
# algo-1-v8ui6_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-v8ui6_1  | INFO:root:No training data found. Saving a randomly initialized model!
# algo-1-v8ui6_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-v8ui6_1  | INFO:VW CLI:successfully created VWModel
# algo-1-v8ui6_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-f', '/opt/ml/model/vw.model', '-p', '/dev/stdout']
# algo-1-v8ui6_1  | INFO:VW CLI:Started VW process!
# algo-1-v8ui6_1  | 2020-09-26 20:27:38,380 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpbdttp7nx/algo-1-v8ui6 Please remove it manually.
# tmpbdttp7nx_algo-1-v8ui6_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# # ^^ Ignore `Failed to delete: /tmp/...` message above.  This is OK. ^^

# %% [markdown]
# # Check Experiment State:  TRAINED
# `training_state`: `TRAINED`
#
# Remember the `last_trained_model_id`.

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601151981',
#  'training_workflow_metadata': {'last_trained_model_id': 'bandits-1601151981-model-id-1601152031',
#   'next_model_to_train_id': None,
#   'training_state': <TrainingState.TRAINED: 'TRAINED'>},
#  'hosting_workflow_metadata': {'last_hosted_model_id': None,
#   'hosting_endpoint': None,
#   'hosting_state': None,
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': None,
#   'next_join_job_id': None,
#   'last_joined_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Deploy the Bandit Model

# %% [markdown]
# Once training and evaluation is done, we can deploy the model.

# %%
import boto3
account_id = boto3.client('sts').get_caller_identity().get('Account')
region = boto3.session.Session().region_name

# !$(aws ecr get-login --region $region --registry-ids $account_id --no-include-email)
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
print('Deploying newly-trained bandit model: {}'.format(bandit_experiment_manager.last_trained_model_id))
# Out:
# Deploying newly-trained bandit model: bandits-1601151981-model-id-1601152031

# %%
print('Deploying bandit model_id {}'.format(bandit_experiment_manager.last_trained_model_id))

bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
# Out:
# Deploying bandit model_id bandits-1601151981-model-id-1601152031
# INFO:orchestrator:Model 'bandits-1601151981-model-id-1601152031' is ready to deploy.
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fcfb0c7c898>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fcfb0c7c978>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fcfb0c7cb70>: Failed to establish a new connection: [Errno 111] Connection refused',)': /ping
# Attaching to tmpe_qwuf7__algo-1-ko0fh_1
# algo-1-ko0fh_1  | 17:C 26 Sep 2020 20:27:54.390 # oO0OoO0OoO0Oo Redis is starting oO0OoO0OoO0Oo
# algo-1-ko0fh_1  | 17:C 26 Sep 2020 20:27:54.391 # Redis version=5.0.6, bits=64, commit=00000000, modified=0, pid=17, just started
# algo-1-ko0fh_1  | 17:C 26 Sep 2020 20:27:54.391 # Configuration loaded
# algo-1-ko0fh_1  | 17:M 26 Sep 2020 20:27:54.391 # You requested maxclients of 10000 requiring at least 10032 max file descriptors.
# algo-1-ko0fh_1  | 17:M 26 Sep 2020 20:27:54.391 # Server can't set maximum open files to 10032 because of OS error: Operation not permitted.
# algo-1-ko0fh_1  | 17:M 26 Sep 2020 20:27:54.391 # Current maximum open files is 4096. maxclients has been reduced to 4064 to compensate for low ulimit. If you need higher maxclients increase 'ulimit -n'.
# algo-1-ko0fh_1  | 17:M 26 Sep 2020 20:27:54.392 # WARNING: The TCP backlog setting of 511 cannot be enforced because /proc/sys/net/core/somaxconn is set to the lower value of 128.
# algo-1-ko0fh_1  | 17:M 26 Sep 2020 20:27:54.392 # Server initialized
# algo-1-ko0fh_1  | 17:M 26 Sep 2020 20:27:54.392 # WARNING overcommit_memory is set to 0! Background save may fail under low memory condition. To fix this issue add 'vm.overcommit_memory = 1' to /etc/sysctl.conf and then reboot or run the command 'sysctl vm.overcommit_memory=1' for this to take effect.
# algo-1-ko0fh_1  | 17:M 26 Sep 2020 20:27:54.392 # WARNING you have Transparent Huge Pages (THP) support enabled in your kernel. This will create latency and memory usage issues with Redis. To fix this issue run the command 'echo never > /sys/kernel/mm/transparent_hugepage/enabled' as root, and add it to your /etc/rc.local in order to retain the setting after a reboot. Redis must be restarted after THP is disabled.
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Redis server started successfully!
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Starting gunicorn...
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Started server process with PID: 23
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Started gunicorn.
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 WARNING 139964419942144] Loggers have already been setup.
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144 integration.py:348] worker started
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] loading entry points
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Number of server workers: 8
# algo-1-ko0fh_1  | [2020-09-26 20:27:57 +0000] [23] [INFO] Starting gunicorn 19.9.0
# algo-1-ko0fh_1  | [2020-09-26 20:27:57 +0000] [23] [INFO] Listening at: http://0.0.0.0:8080 (23)
# algo-1-ko0fh_1  | [2020-09-26 20:27:57 +0000] [23] [INFO] Using worker: sync
# algo-1-ko0fh_1  | [2020-09-26 20:27:57 +0000] [24] [INFO] Booting worker with pid: 24
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152031
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [2020-09-26 20:27:57 +0000] [27] [INFO] Booting worker with pid: 27
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152031
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [2020-09-26 20:27:57 +0000] [30] [INFO] Booting worker with pid: 30
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152031
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Started VW process!
# !algo-1-ko0fh_1  | [2020-09-26 20:27:57 +0000] [33] [INFO] Booting worker with pid: 33
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/model/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152031
# algo-1-ko0fh_1  | [09/26/2020 20:27:57 INFO 139964419942144] Started VW process!

# %% [markdown]
# # Check Experiment State:  DEPLOYED
# `hosting_state`: `DEPLOYED`
#
# The `last_trained_model_id` and `last_hosted_model_id` are now the same as we just deployed the bandit model.

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601151981',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601151981-model-id-1601152031',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601151981-model-id-1601152031',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': None,
#   'next_join_job_id': None,
#   'last_joined_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Initialize the Client Application

# %%
import csv
import numpy as np

class ClientApp():
    def __init__(self, data, num_events, bandit_model, bert_model_map):
        self.bandit_model = bandit_model
        self.bert_model_map = bert_model_map
        
        self.num_actions = 2

        df_reviews = pd.read_csv(data, 
                                 delimiter='\t', 
                                 quoting=csv.QUOTE_NONE,
                                 compression='gzip')
        df_scrubbed = df_reviews[['review_body', 'star_rating']].sample(n=num_events) # .query('star_rating == 1')
        df_scrubbed = df_scrubbed.reset_index()
        df_scrubbed.shape
        np_reviews = df_scrubbed.to_numpy()

        np_reviews = np.delete(np_reviews, 0, 1)
        
        # Last column is the label, the rest are the features (contexts)
        self.labels = np_reviews[:, -1]
        self.contexts = np_reviews[:, :-1].tolist()

        self.optimal_rewards = [1]
        self.rewards_tmp_buffer = []
        self.joined_data_tmp_buffer = []
        self.all_joined_data_buffer = []
        
        self.action_count = {}

    def increment_action_count(self, action):
        try:
            action_count = self.action_count[action]
        except:
            self.action_count[action] = 0
            action_count = 0
            
        self.action_count[action] = action_count + 1
                
    def choose_random_context(self):
        context_index = np.random.choice(len(self.contexts))
        context = self.contexts[context_index]
        return context_index, context    

    def clear_tmp_buffers(self):
        self.rewards_tmp_buffer.clear()
        self.joined_data_tmp_buffer.clear()

    def get_reward(self, 
                   context_index, 
                   action, 
                   event_id, 
                   bandit_model_id, 
                   action_prob, 
                   sample_prob, 
                   local_mode):

        context_to_predict = self.contexts[context_index][0]
    
        label = self.labels[context_index]
        
        bert_model = self.bert_model_map[action]

        self.increment_action_count(action)
        
        # TensorFlow returns [str]
        if (action == 1):
            bert_predicted_class = bert_model.predict(context_to_predict)[0]
            bert_predicted_class
            print('Predicted Class from Model 1: {}, Actual Class: {}'.format(bert_predicted_class, label))

        # PyTorch returns bytes
        if (action == 2):
            bert_predicted_class = bert_model.predict(context_to_predict)
            bert_predicted_class = bert_predicted_class.decode('utf-8')
            print('Predicted Class from Model 2: {}, Actual Class: {}'.format(bert_predicted_class, label))
            
       # Calculate difference between predicted and actual label
        if abs(int(bert_predicted_class) - int(label)) == 0:
            reward = 1
        else:
            reward = 0

        if local_mode:
            json_blob = {
                         "reward": reward,
                         "event_id": event_id,
                         "action": action,
                         "action_prob": action_prob,
                         "model_id": bandit_model_id,
                         "observation": [context_index],
                         "sample_prob": sample_prob
                        }
            
            self.joined_data_tmp_buffer.append(json_blob)            
        else:
            json_blob = {
                         "reward": reward, 
                         "event_id": event_id
                        }
            self.rewards_tmp_buffer.append(json_blob)
        
        return reward

# %%
bandit_model = bandit_experiment_manager.predictor

client_app = ClientApp(data='./data/amazon_reviews_us_Digital_Software_v1_00.tsv.gz',
                       num_events=100,
                       bandit_model=bandit_model,
                       bert_model_map={
                         1: model1,
                         2: model2
                       })

# %% [markdown]
# Make sure that `num_arms` specified in `config.yaml` is equal to the total unique actions in the simulation application.

# %%
print('Testing {} BERT models'.format(client_app.num_actions))

assert client_app.num_actions == bandit_experiment_manager.config["algor"]["algorithms_parameters"]["num_arms"]
# Out:
# Testing 2 BERT models

# %%
import time

context_index, context = client_app.choose_random_context()
action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=[context_index])

print('event ID: {}\nbert_model_id: {}\naction_probability: {}'.format(event_id, action, action_prob, bandit_model_id))
# Out:
# event ID: 264926863838561755944136957104722411522
# bert_model_id: 1
# action_probability: 1.0

# %% [markdown]
# # Generate Sample Events to Test the Bandit `ExperimentManager`
# Thsi will generated sample contexts to pass as events to the bandit using the Amazon Customer Reviews Dataset.  The bandit model will recommend an action (BERT model) based on the context and current state of the bandit.  We will assign a reward using the star ratings from Amazon Customer Reviews Dataset.

# %% [markdown]
# Client application generates a reward after receiving the recommended action and stores the tuple `<eventID, reward>` in S3. In this case, reward is 1 if predicted action is the true class, and 0 otherwise. SageMaker hosting endpoint saves all the inferences `<eventID, state, action, action probability>` to S3 using [**Kinesis Firehose**](https://aws.amazon.com/kinesis/data-firehose/). The `ExperimentManager` joins the reward with state, action and action probability using [**Amazon Athena**](https://aws.amazon.com/athena/).

# %%
local_mode = bandit_experiment_manager.local_mode

num_events = 100 

print('Generating {} sample events...'.format(num_events))

for i in range(num_events):
    context_index, context = client_app.choose_random_context()
    action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=[context_index])

    reward = client_app.get_reward(context_index=context_index, 
                                   action=action, 
                                   event_id=event_id, 
                                   bandit_model_id=bandit_model_id, 
                                   action_prob=action_prob, 
                                   sample_prob=sample_prob, 
                                   local_mode=local_mode)
# Out:
# Generating 100 sample events...
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5

# %% [markdown]
# # Create Bandit Model Training Data
#
# Join `Event` and `Reward` data and upload to S3 in the following format:
#
# ```
# {
#  'reward': 0, # 0 if the model is wrong, +1 if the model is correct
#  'event_id': 131181492351609994318271340276526219266, # unique event id
#  'action': 1, # suggested action (bert_model_id 1 or 2)
#  'action_prob': 0.9995, # probability that the suggested action is correct
#  'model_id': 'bandits-1597631299-model-id-1597631304', # unique bandit_model_id
#  'observation': [54], # feature (review_id)
#  'sample_prob': 0.43410828171830174
# }
# ```

# %%
if local_mode:
    print('Using local mode with memory buffers.')
    print()
    print(client_app.joined_data_tmp_buffer)
    bandit_experiment_manager.ingest_joined_data(client_app.joined_data_tmp_buffer)
else:
    print("Using production mode with Kinesis Firehose.  Waiting to flush to S3...")
    print()
    time.sleep(60) # Wait for firehose to flush data to S3
    rewards_s3_prefix = bandit_experiment_manager.ingest_rewards(client_app.rewards_tmp_buffer)
    bandit_experiment_manager.join(rewards_s3_prefix)
# Out:
# Using local mode with memory buffers.
#
# [{'reward': 1, 'event_id': 264933061065433621700623524112517693442, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [35], 'sample_prob': 0.4624336533600404}, {'reward': 0, 'event_id': 265109846033578200287669502470660423682, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [33], 'sample_prob': 0.7087945973653031}, {'reward': 1, 'event_id': 265271084851674229928004038401560018946, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [64], 'sample_prob': 0.6540652604704026}, {'reward': 0, 'event_id': 265394299697734788683186142017683062786, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [6], 'sample_prob': 0.8816931874110062}, {'reward': 0, 'event_id': 265529893944188201241117236876046106626, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [52], 'sample_prob': 0.09569793279492778}, {'reward': 0, 'event_id': 265813276443587596780651246310789349378, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [74], 'sample_prob': 0.3121766568156359}, {'reward': 1, 'event_id': 265932303288977651523475357825076690946, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [56], 'sample_prob': 0.19477659852057227}, {'reward': 0, 'event_id': 266027180598151733352503175945103998978, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [14], 'sample_prob': 0.9511053285509942}, {'reward': 1, 'event_id': 266145193323061605511105780354770927618, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [87], 'sample_prob': 0.42951411523735195}, {'reward': 0, 'event_id': 266245641164342065266237003181325418498, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [73], 'sample_prob': 0.46927052138720826}, {'reward': 0, 'event_id': 266354809649470470097180254501170446338, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [33], 'sample_prob': 0.3360039861876788}, {'reward': 0, 'event_id': 266490106790314454164372576201098788866, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [1], 'sample_prob': 0.12340477018700025}, {'reward': 1, 'event_id': 266610888539504199861747182082507014146, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [86], 'sample_prob': 0.13559561872106474}, {'reward': 1, 'event_id': 266731097469078967427960986641154310146, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [15], 'sample_prob': 0.9144497824392789}, {'reward': 0, 'event_id': 266869701593426296888077260234190618626, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [55], 'sample_prob': 0.42334182928846564}, {'reward': 0, 'event_id': 266995797967757499436517331301731270658, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [59], 'sample_prob': 0.4952569305979986}, {'reward': 1, 'event_id': 267126799357629960090798128417293336578, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [88], 'sample_prob': 0.9944521168064959}, {'reward': 1, 'event_id': 267228477612274266371265286092073598978, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [63], 'sample_prob': 0.18430804026086456}, {'reward': 0, 'event_id': 267331875910326757330855695126717661186, 'action': 1, 'action_prob': 1.0, 'model_id': 'bandits-1601151981-model-id-1601152031', 'observation': [0], 'sample_prob': 0.1343 ...
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.8
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152099
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152099/train/local-joined-data-1601152100.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152099/eval/local-joined-data-1601152100.csv

# %% [markdown]
# # Check Experiment Status:  JOINED
# `joining_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601151981',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601151981-model-id-1601152031',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': 'DEPLOYED',
#   'last_hosted_model_id': 'bandits-1601151981-model-id-1601152031',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601151981-join-job-id-1601152099',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Review Bandit Model Training Data

# %%
print('Bandit model training data {}'.format(bandit_experiment_manager.last_joined_job_train_data))
# Out:
# Bandit model training data s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152099/train

# %%
from sagemaker.s3 import S3Downloader

bandit_model_train_data_s3_uri = S3Downloader.list(bandit_experiment_manager.last_joined_job_train_data)[0]
print(bandit_model_train_data_s3_uri)
# Out:
# s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152099/train/local-joined-data-1601152100.csv

# %%
from sagemaker.s3 import S3Downloader

bandit_model_train_data = S3Downloader.read_file(bandit_model_train_data_s3_uri)
print(bandit_model_train_data)
# Out:
# "reward","event_id","action","action_prob","model_id","observation","sample_prob"
# "1","264933061065433621700623524112517693442","1","1.0","bandits-1601151981-model-id-1601152031","[35]","0.4624336533600404"
# "0","265109846033578200287669502470660423682","1","1.0","bandits-1601151981-model-id-1601152031","[33]","0.7087945973653031"
# "1","265271084851674229928004038401560018946","1","1.0","bandits-1601151981-model-id-1601152031","[64]","0.6540652604704026"
# "0","265529893944188201241117236876046106626","1","1.0","bandits-1601151981-model-id-1601152031","[52]","0.09569793279492778"
# "0","265813276443587596780651246310789349378","1","1.0","bandits-1601151981-model-id-1601152031","[74]","0.3121766568156359"
# "1","265932303288977651523475357825076690946","1","1.0","bandits-1601151981-model-id-1601152031","[56]","0.19477659852057227"
# "1","266145193323061605511105780354770927618","1","1.0","bandits-1601151981-model-id-1601152031","[87]","0.42951411523735195"
# "0","266245641164342065266237003181325418498","1","1.0","bandits-1601151981-model-id-1601152031","[73]","0.46927052138720826"
# "0","266354809649470470097180254501170446338","1","1.0","bandits-1601151981-model-id-1601152031","[33]","0.3360039861876788"
# "0","266490106790314454164372576201098788866","1","1.0","bandits-1601151981-model-id-1601152031","[1]","0.12340477018700025"
# "1","266610888539504199861747182082507014146","1","1.0","bandits-1601151981-model-id-1601152031","[86]","0.13559561872106474"
# "0","266869701593426296888077260234190618626","1","1.0","bandits-1601151981-model-id-1601152031","[55]","0.42334182928846564"
# "0","266995797967757499436517331301731270658","1","1.0","bandits-1601151981-model-id-1601152031","[59]","0.4952569305979986"
# "1","267228477612274266371265286092073598978","1","1.0","bandits-1601151981-model-id-1601152031","[63]","0.18430804026086456"
# "0","267331875910326757330855695126717661186","1","1.0","bandits-1601151981-model-id-1601152031","[0]","0.13432839133239882"
# "0","267696218499872979026930246013930307586","1","1.0","bandits-1601151981-model-id-1601152031","[74]","0.06194569216233192"
# "1","267800292614151716660265922715712618498","1","1.0","bandits-1601151981-model-id-1601152031","[66]","0.7215065410753573"
# "0","268036566840401755767664282373727584258","1","1.0","bandits-1601151981-model-id-1601152031","[72]","0.08805334441737167"
# "0","268135844481721879839229558298191724546","1","1.0","bandits-1601151981-model-id-1601152031","[27]","0.5305191519804658"
# "1","268244932154124520120375357092530356226","1","1.0","bandits-1601151981-model-id-1601152031","[83]","0.0461795743069775"
# "1","268345165287084566218624498783600377858","1","1.0","bandits-1601151981-model-id-1601152031","[89]","0.3933912247345116"
# "0","268486620040719158909607388087969775618","1","1.0","bandits-1601151981-model-id-1601152031","[24]","0.29988107983040013"
# "1","268597008639550283411176472873972924418","1","1.0","bandits-1601151981-model-id-1601152031","[43]","0.7155699895664785"
# "1","268718680121005064297062254253943422978","1","1.0","bandits-1601151981-model-id-1601152031","[47]","0.4087996916922727"
# "0","268818401440035268248217744282473332738","1","1.0","bandits-1601151981-model-id-1601152031","[74]","0.7771444247371345"
# "0","268911293291456742613472670822484279298","1","1.0","bandits-1601151981-model-id-1601152031","[55]","0.7904274217563267"
# "0","269038303958783359773068881129267920898","1","1.0","bandits-1601151981-model-id-1601152031","[34]","0.49948431646994296"
# "0","269406751359429445504474153528547475458","1","1.0","bandits-1601151981-model-id-1601152031","[19]","0.796342122391531"
# "1","269524742692735438811705607681347813378","1","1.0","bandits-1601151981-model-id-1601152031","[75]","0.1867286511724202"
# "0","269880620545398636506124771443583614978","1","1.0","bandits-1601151981-model-id-1601152031","[76]","0.1315894544347962"
# "1","269987560342315515081078409261428637698","1","1.0","bandits-1601151981-model-id-1601152031","[37]","0.0025018884465558555"
# "1","270167844026116723581272518520418205698","1","1.0","bandits-1601151981-model-id-1601152031","[66]","0.24627308354840094"
# "1","270272084519536741170244344295875280898","1","1.0","bandits-1601151981-model-id-1601152031","[75]","0.39846398981945996"
# "1","270374912374819129424992917047385128962","1","1.0","bandits-1601151981-model-id-1601152031","[63]","0.2810231401042912"
# "1","270579440668631327956745189457308811266","1","1.0","bandits-1601151981-model-id-1601152031","[16]","0.5165143354681343"
# "0","270683611441268332993099932914089590786","1","1.0","bandits-1601151981-model-id-1601152031","[77]","0.27361147230003036"
# "0","271068498685636128574028663051684806658","1","1.0","bandits-1601151981-model-id-1601152031","[25]","0.5273649909743032"
# "0","271175946335074723583213168375574429698","1","1.0","bandits-1601151981-model-id-1601152031","[9]","0.1530279490143559"
# "1","271306504047237104357203441645014614018","1","1.0","bandits-1601151981-model-id-1601152031","[39]","0.5325246787478883"
# "0","271408889809372663018732512298650435586","1","1.0","bandits-1601151981-model-id-1601152031","[93]","0.16853516992301598"
# "0","271658133685826287197667732469956345858","1","1.0","bandits-1601151981-model-id-1601152031","[24]","0.2984719833989682"
# "0","271786912725740222737979340419767599106","1","1.0","bandits-1601151981-model-id-1601152031","[60]","0.6477567735837868"
# "1","271891968476952512105373840995781836802","1","1.0","bandits-1601151981-model-id-1601152031","[94]","0.32524730428950976"
# "0","272020833875563588194724278933134639106","1","1.0","bandits-1601151981-model-id-1601152031","[19]","0.798096564136535"
# "1","272137045744339511125106489199487483906","1","1.0","bandits-1601151981-model-id-1601152031","[75]","0.3359128770567946"
# "1","272258718018075917153635646514897485826","1","1.0","bandits-1601151981-model-id-1601152031","[15]","0.06282658400851104"
# "0","272488508211505788867818457646694006786","1","1.0","bandits-1601151981-model-id-1601152031","[5]","0.6151001080443564"
# "1","272758367255845624628095827695933456386","1","1.0","bandits-1601151981-model-id-1601152031","[53]","0.5164362697621695"
# "1","272851971368448102229218517564678864898","1","1.0","bandits-1601151981-model-id-1601152031","[64]","0.6363063268651636"
# "1","272970463423741185687763872657301438466","1","1.0","bandits-1601151981-model-id-1601152031","[15]","0.13222006847922196"
# "1","273082290013721944087060280266003185666","1","1.0","bandits-1601151981-model-id-1601152031","[39]","0.7073903319316517"
# "0","273190895978896497641033510313123774466","1","1.0","bandits-1601151981-model-id-1601152031","[23]","0.1175908284733822"
# "1","273362082685077818309985128855735762946","1","1.0","bandits-1601151981-model-id-1601152031","[30]","0.37587374588357625"
# "0","273487161769802337705030808561010212866","1","1.0","bandits-1601151981-model-id-1601152031","[98]","0.22425554907075596"
# "1","273582989816926590705936642097764499458","1","1.0","bandits-1601151981-model-id-1601152031","[67]","0.7008181993481164"
# "1","273692233568809384087827500173685293058","1","1.0","bandits-1601151981-model-id-1601152031","[75]","0.21464791416471152"
# "0","273813547731251225642251044412495888386","1","1.0","bandits-1601151981-model-id-1601152031","[95]","0.5639075318326678"
# "0","274036964019006824790474454933487878146","1","1.0","bandits-1601151981-model-id-1601152031","[32]","0.6837857758748881"
# "1","274147473044644970973836681906295537666","1","1.0","bandits-1601151981-model-id-1601152031","[45]","0.6053211984135376"
# "1","274251722253162865130274480204895354882","1","1.0","bandits-1601151981-model-id-1601152031","[89]","0.4842052538379502"
# "0","274560617013173478930595042383101034498","1","1.0","bandits-1601151981-model-id-1601152031","[93]","0.4352932094898556"
# "1","274720628587032162615429401293574242306","1","1.0","bandits-1601151981-model-id-1601152031","[86]","0.75765129793018"
# "0","274834356652913263358828053957084053506","1","1.0","bandits-1601151981-model-id-1601152031","[26]","0.36698677268430635"
# "1","274957555653341319261142638864417030146","1","1.0","bandits-1601151981-model-id-1601152031","[87]","0.5429565878951599"
# "0","275076656973204137411389683047259570178","1","1.0","bandits-1601151981-model-id-1601152031","[36]","0.07432492784927536"
# "0","275192864088290309486438840332354453506","1","1.0","bandits-1601151981-model-id-1601152031","[98]","0.5573019044347568"
# "1","275570085215653224850589221788694216706","1","1.0","bandits-1601151981-model-id-1601152031","[86]","0.003098712136689441"
# "1","275916253657000299450263189629139288066","1","1.0","bandits-1601151981-model-id-1601152031","[86]","0.2707471990248056"
# "0","276023154632117546035691406610448646146","1","1.0","bandits-1601151981-model-id-1601152031","[0]","0.10372868657497158"
# "0","276288985716675156597045520885253013506","1","1.0","bandits-1601151981-model-id-1601152031","[17]","0.2049596415859306"
# "1","276493914904989677304734853860873601026","1","1.0","bandits-1601151981-model-id-1601152031","[53]","0.060397332945044124"
# "1","276593709906211019520113143118585528322","1","1.0","bandits-1601151981-model-id-1601152031","[28]","0.39697208376635706"
# "1","276752126617158291064215394382595096578","1","1.0","bandits-1601151981-model-id-1601152031","[63]","0.49501039047316375"
# "1","276847682119403494997027418501595398146","1","1.0","bandits-1601151981-model-id-1601152031","[45]","0.19084006462437142"
# "1","276949075152662749925178929676098338818","1","1.0","bandits-1601151981-model-id-1601152031","[2]","0.41985652641774296"
# "1","277150473934055635014512296964671012866","1","1.0","bandits-1601151981-model-id-1601152031","[22]","0.08404705804858492"
# "1","277279950974081321222937794294628614146","1","1.0","bandits-1601151981-model-id-1601152031","[86]","0.3096339296538193"
# "1","277390951214327055845193101239928356866","1","1.0","bandits-1601151981-model-id-1601152031","[30]","0.5844078110160388"
# "0","277505187925011498165639104455599325186","1","1.0","bandits-1601151981-model-id-1601152031","[26]","0.39437552168455303"
# "0","277619259841117910814651750333161799682","1","1.0","bandits-1601151981-model-id-1601152031","[41]","0.18690266249183896"

# %% [markdown]
# # Train the Bandit Model

# %% [markdown]
# Now we can train a new model with newly collected experiences, and host the resulting model.

# %%
print('Trained bandit model id {}'.format(bandit_experiment_manager.last_trained_model_id))

bandit_experiment_manager.train_next_model(input_data_s3_prefix=bandit_experiment_manager.last_joined_job_train_data)
# Out:
# Trained bandit model id bandits-1601151981-model-id-1601152031
# INFO:orchestrator:Use last trained model bandits-1601151981-model-id-1601152031 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601151981-model-id-1601152109''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpzcegknbl_algo-1-ap9ah_1 ...
# Attaching to tmpzcegknbl_algo-1-ap9ah_12mdone
# algo-1-ap9ah_1  | 2020-09-26 20:28:33,864 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ap9ah_1  | 2020-09-26 20:28:33,877 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ap9ah_1  | 2020-09-26 20:28:33,888 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ap9ah_1  | 2020-09-26 20:28:33,897 sagemaker-containers INFO     Invoking user script
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | Training Env:
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | {
# algo-1-ap9ah_1  |     "additional_framework_parameters": {
# algo-1-ap9ah_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-ap9ah_1  |     },
# algo-1-ap9ah_1  |     "channel_input_dirs": {
# algo-1-ap9ah_1  |         "training": "/opt/ml/input/data/training",
# algo-1-ap9ah_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-ap9ah_1  |     },
# algo-1-ap9ah_1  |     "current_host": "algo-1-ap9ah",
# algo-1-ap9ah_1  |     "framework_module": null,
# algo-1-ap9ah_1  |     "hosts": [
# algo-1-ap9ah_1  |         "algo-1-ap9ah"
# algo-1-ap9ah_1  |     ],
# algo-1-ap9ah_1  |     "hyperparameters": {
# algo-1-ap9ah_1  |         "exploration_policy": "cover",
# algo-1-ap9ah_1  |         "epsilon": 0.1,
# algo-1-ap9ah_1  |         "num_policies": 3,
# algo-1-ap9ah_1  |         "num_arms": 2,
# algo-1-ap9ah_1  |         "cfa_type": "dr"
# algo-1-ap9ah_1  |     },
# algo-1-ap9ah_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-ap9ah_1  |     "input_data_config": {
# algo-1-ap9ah_1  |         "training": {
# algo-1-ap9ah_1  |             "TrainingInputMode": "File"
# algo-1-ap9ah_1  |         },
# algo-1-ap9ah_1  |         "pretrained_model": {
# algo-1-ap9ah_1  |             "TrainingInputMode": "File",
# algo-1-ap9ah_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-ap9ah_1  |         }
# algo-1-ap9ah_1  |     },
# algo-1-ap9ah_1  |     "input_dir": "/opt/ml/input",
# algo-1-ap9ah_1  |     "is_master": true,
# algo-1-ap9ah_1  |     "job_name": "bandits-1601151981-model-id-1601152109",
# algo-1-ap9ah_1  |     "log_level": 20,
# algo-1-ap9ah_1  |     "master_hostname": "algo-1-ap9ah",
# algo-1-ap9ah_1  |     "model_dir": "/opt/ml/model",
# algo-1-ap9ah_1  |     "module_dir": "s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152109/source/sourcedir.tar.gz",
# algo-1-ap9ah_1  |     "module_name": "train-vw",
# algo-1-ap9ah_1  |     "network_interface_name": "eth0",
# algo-1-ap9ah_1  |     "num_cpus": 8,
# algo-1-ap9ah_1  |     "num_gpus": 0,
# algo-1-ap9ah_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-ap9ah_1  |     "output_dir": "/opt/ml/output",
# algo-1-ap9ah_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-ap9ah_1  |     "resource_config": {
# algo-1-ap9ah_1  |         "current_host": "algo-1-ap9ah",
# algo-1-ap9ah_1  |         "hosts": [
# algo-1-ap9ah_1  |             "algo-1-ap9ah"
# algo-1-ap9ah_1  |         ]
# algo-1-ap9ah_1  |     },
# algo-1-ap9ah_1  |     "user_entry_point": "train-vw.py"
# algo-1-ap9ah_1  | }
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | Environment variables:
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | SM_HOSTS=["algo-1-ap9ah"]
# algo-1-ap9ah_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-ap9ah_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-ap9ah_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-ap9ah_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-ap9ah_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-ap9ah","hosts":["algo-1-ap9ah"]}
# algo-1-ap9ah_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-ap9ah_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-ap9ah_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-ap9ah_1  | SM_CURRENT_HOST=algo-1-ap9ah
# algo-1-ap9ah_1  | SM_MODULE_NAME=train-vw
# algo-1-ap9ah_1  | SM_LOG_LEVEL=20
# algo-1-ap9ah_1  | SM_FRAMEWORK_MODULE=
# algo-1-ap9ah_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-ap9ah_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-ap9ah_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-ap9ah_1  | SM_NUM_CPUS=8
# algo-1-ap9ah_1  | SM_NUM_GPUS=0
# algo-1-ap9ah_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-ap9ah_1  | SM_MODULE_DIR=s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152109/source/sourcedir.tar.gz
# algo-1-ap9ah_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-ap9ah","framework_module":null,"hosts":["algo-1-ap9ah"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601151981-model-id-1601152109","log_level":20,"master_hostname":"algo-1-ap9ah","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152109/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ap9ah","hosts":["algo-1-ap9ah"]},"user_entry_point":"train-vw.py"}
# algo-1-ap9ah_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-ap9ah_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-ap9ah_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-ap9ah_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-ap9ah_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-ap9ah_1  | SM_HP_EPSILON=0.1
# algo-1-ap9ah_1  | SM_HP_NUM_POLICIES=3
# algo-1-ap9ah_1  | SM_HP_NUM_ARMS=2
# algo-1-ap9ah_1  | SM_HP_CFA_TYPE=dr
# algo-1-ap9ah_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | Invoking script with the following command:
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-ap9ah_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-ap9ah_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-ap9ah_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-ap9ah_1  | INFO:VW CLI:successfully created VWModel
# algo-1-ap9ah_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-ap9ah_1  | INFO:VW CLI:Started VW process!
# algo-1-ap9ah_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152100.csv')]
# algo-1-ap9ah_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-ap9ah_1  | predictions = /dev/stdout
# algo-1-ap9ah_1  | Num weight bits = 18
# algo-1-ap9ah_1  | learning rate = 0.5
# algo-1-ap9ah_1  | initial_t = 0
# algo-1-ap9ah_1  | power_t = 0.5
# algo-1-ap9ah_1  | using no cache
# algo-1-ap9ah_1  | Reading datafile =
# algo-1-ap9ah_1  | num sources = 1
# algo-1-ap9ah_1  | average  since         example        example  current  current  current
# algo-1-ap9ah_1  | loss     last          counter         weight    label  predict features
# algo-1-ap9ah_1  | 0.000000 0.000000            1            1.0        1 1:1.000000        2
# algo-1-ap9ah_1  | 0.250000 0.500000            2            2.0        1 1:0.500000        2
# algo-1-ap9ah_1  | 0.125000 0.000000            4            4.0        1 2:1.000000        2
# algo-1-ap9ah_1  | 0.104167 0.083333            8            8.0        1 2:0.666667        2
# algo-1-ap9ah_1  | 0.156250 0.208333           16           16.0        1 2:0.666667        2
# algo-1-ap9ah_1  | 0.119792 0.083333           32           32.0        1 2:1.000000        2
# algo-1-ap9ah_1  | 0.117188 0.114583           64           64.0        1 2:1.000000        2
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | finished run
# algo-1-ap9ah_1  | number of examples = 80
# algo-1-ap9ah_1  | weighted example sum = 80.000000
# algo-1-ap9ah_1  | weighted label sum = 0.000000
# algo-1-ap9ah_1  | average loss = 0.114583
# algo-1-ap9ah_1  | total feature number = 158
# algo-1-ap9ah_1  |
# algo-1-ap9ah_1  | INFO:root:Model learned using 80 training experiences.
# algo-1-ap9ah_1  | 2020-09-26 20:28:34,332 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpzcegknbl/algo-1-ap9ah Please remove it manually.
# tmpzcegknbl_algo-1-ap9ah_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# # Ignore ^^ `Failed to delete` Error Above ^^

# %% [markdown]
# # Deploy the Bandit Model

# %%
print('Deploying bandit model id {}'.format(bandit_experiment_manager.last_hosted_model_id))

bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
# Out:
# Deploying bandit model id bandits-1601151981-model-id-1601152031
# INFO:orchestrator:Model 'bandits-1601151981-model-id-1601152109' is ready to deploy.
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Found new model! Trying to replace Model ID: bandits-1601151981-model-id-1601152031 with Model ID: bandits-1601151981-model-id-1601152109
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [23] [INFO] Handling signal: hup
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [23] [INFO] Hang up: Master
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [38] [INFO] Booting worker with pid: 38
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [39] [INFO] Booting worker with pid: 39
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Q1eDdK90/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152109
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [40] [INFO] Booting worker with pid: 40
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [24] [INFO] Worker exiting (pid: 24)
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [33] [INFO] Worker exiting (pid: 33)
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [30] [INFO] Worker exiting (pid: 30)
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [27] [INFO] Worker exiting (pid: 27)
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Q1eDdK90/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152109
# algo-1-ko0fh_1  | [2020-09-26 20:28:44 +0000] [41] [INFO] Booting worker with pid: 41
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Q1eDdK90/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Q1eDdK90/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152109
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152109
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:28:44 INFO 139964419942144] Started VW process!

# %% [markdown]
# # Check Experiment Status:  DEPLOYED
# `deploying_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601151981',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601151981-model-id-1601152109',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601151981-model-id-1601152109',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601151981-join-job-id-1601152099',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': None,
#   'last_evaluation_job_id': None,
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Continuously Train, Evaluate, and Deploy Bandit Models
# The above cells explained the individual steps in the training workflow. To train a model to convergence, we will continually train the model based on data collected with client application interactions. We demonstrate the continual training and evaluation loop in a single cell below.
#
# _**Train and Evaluate**_:
# After every training cycle, we evaluate if the newly trained model (`last_trained_model_id`) would perform better than the one currently deployed (`last_hosted_model_id`) using a holdout evaluation dataset.  Details of the join, train, and evaluation steps are tracked in the `BanditsJoinTable` and `BanditsModelTable` DynamoDB tables.  When you have multiple experiments, you can compare them in the `BanditsExperimentTable` DynamoDB table.
#
# _**Deploy**_: If the new bandit model is better than the current bandit model (based on offline evaluation), we will automatically deploy the new bandit model using a blue-green deployment to avoid downtime.

# %%
do_evaluation = True
total_loops = 5 # Increase for higher accuracy
retrain_batch_size = 100 # Model will be trained after every `batch_size` number of data instances
rewards_list = []
event_list = []

all_joined_train_data_s3_uri_list = []
all_joined_eval_data_s3_uri_list = []

local_mode = bandit_experiment_manager.local_mode

start_time = time.time()
for loop_no in range(total_loops):
    print(f"""
    ################################
    # Incremental Training Loop {loop_no+1}
    ################################
    """)
    
    # Generate experiences and log them
    for i in range(retrain_batch_size):
        context_index, context = client_app.choose_random_context()
        action, event_id, bandit_model_id, action_prob, sample_prob = bandit_model.get_action(obs=[context_index])

        reward = client_app.get_reward(context_index=context_index, 
                                       action=action, 
                                       event_id=event_id, 
                                       bandit_model_id=bandit_model_id, 
                                       action_prob=action_prob, 
                                       sample_prob=sample_prob, 
                                       local_mode=local_mode)

        rewards_list.append(reward)
        
    # Publish rewards sum for this batch to CloudWatch for monitoring 
    bandit_experiment_manager.cw_logger.publish_rewards_for_simulation(
        bandit_experiment_manager.experiment_id,
        sum(rewards_list[-retrain_batch_size:])/retrain_batch_size
    )
    
    # Join the events and rewards data to use for the next bandit-model training job
    # Use 90% as the training dataset and 10% as the the holdout evaluation dataset
    if local_mode:        
        bandit_experiment_manager.ingest_joined_data(client_app.joined_data_tmp_buffer,
                                                     ratio=0.90)
    else:
        # Kinesis Firehose => S3 => Athena
        print('Waiting for firehose to flush data to s3...')
        time.sleep(60) 
        rewards_s3_prefix = bandit_experiment_manager.ingest_rewards(client_app.rewards_tmp_buffer)
        bandit_experiment_manager.join(rewards_s3_prefix, ratio=0.90)
            
    # Train 
    bandit_experiment_manager.train_next_model(
        input_data_s3_prefix=bandit_experiment_manager.last_joined_job_train_data)

    all_joined_train_data_s3_uri_list.append(bandit_experiment_manager.last_joined_job_train_data)

    # Evaluate and/or deploy the new bandit model
    if do_evaluation:
        bandit_experiment_manager.evaluate_model(
            input_data_s3_prefix=bandit_experiment_manager.last_joined_job_eval_data,
            evaluate_model_id=bandit_experiment_manager.last_trained_model_id)

        eval_score_last_trained_model = bandit_experiment_manager.get_eval_score(
            evaluate_model_id=bandit_experiment_manager.last_trained_model_id,
            eval_data_path=bandit_experiment_manager.last_joined_job_eval_data)

        bandit_experiment_manager.evaluate_model(
            input_data_s3_prefix=bandit_experiment_manager.last_joined_job_eval_data,
            evaluate_model_id=bandit_experiment_manager.last_hosted_model_id) 

        all_joined_eval_data_s3_uri_list.append(bandit_experiment_manager.last_joined_job_eval_data)
    
        # Eval score is a measure of `regret`, so a lower eval score is better
        eval_score_last_hosted_model = bandit_experiment_manager.get_eval_score(
            evaluate_model_id=bandit_experiment_manager.last_hosted_model_id, 
            eval_data_path=bandit_experiment_manager.last_joined_job_eval_data)
    
        print('New bandit model evaluation score {}'.format(eval_score_last_hosted_model))
        print('Current bandit model evaluation score {}'.format(eval_score_last_trained_model))

        if eval_score_last_trained_model <= eval_score_last_hosted_model:
            print('Deploying new bandit model id {} in loop {}'.format(bandit_experiment_manager.last_trained_model_id, loop_no))
            bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
        else:
            print('Not deploying bandit model id {} in loop {}'.format(bandit_experiment_manager.last_trained_model_id, loop_no))
    else:
        # Just deploy the new bandit model without evaluating against previous model
        print('Deploying new bandit model id {} in loop {}'.format(bandit_experiment_manager.last_trained_model_id, loop_no))
        bandit_experiment_manager.deploy_model(model_id=bandit_experiment_manager.last_trained_model_id)
    
    client_app.clear_tmp_buffers()
    
print(f'Total time taken to complete {total_loops} loops: {time.time() - start_time}')
# Out:
#     ################################
#     # Incremental Training Loop 1
#     ################################
#
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 2
# Predicted Class from Model 2: 4, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 2
# Predicted Class from Model 2: 5, Actual Class: 2
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 2
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 2: 2, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 3
# Predicted Class from Model 2: 4, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 2: 3, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 3, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 4
# Predicted Class from Model 2: 2, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 2: 2, Actual Class: 2
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 4
# Predicted Class from Model 2: 4, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 2: 3, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 2, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 2, Actual Class: 1
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152142
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152142/train/local-joined-data-1601152143.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152142/eval/local-joined-data-1601152143.csv
# INFO:orchestrator:Use last trained model bandits-1601151981-model-id-1601152109 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601151981-model-id-1601152151''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpitv0x61h_algo-1-qw37t_1 ...
# Attaching to tmpitv0x61h_algo-1-qw37t_12mdone
# algo-1-qw37t_1  | 2020-09-26 20:29:16,568 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-qw37t_1  | 2020-09-26 20:29:16,580 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-qw37t_1  | 2020-09-26 20:29:16,591 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-qw37t_1  | 2020-09-26 20:29:16,601 sagemaker-containers INFO     Invoking user script
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | Training Env:
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | {
# algo-1-qw37t_1  |     "additional_framework_parameters": {
# algo-1-qw37t_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-qw37t_1  |     },
# algo-1-qw37t_1  |     "channel_input_dirs": {
# algo-1-qw37t_1  |         "training": "/opt/ml/input/data/training",
# algo-1-qw37t_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-qw37t_1  |     },
# algo-1-qw37t_1  |     "current_host": "algo-1-qw37t",
# algo-1-qw37t_1  |     "framework_module": null,
# algo-1-qw37t_1  |     "hosts": [
# algo-1-qw37t_1  |         "algo-1-qw37t"
# algo-1-qw37t_1  |     ],
# algo-1-qw37t_1  |     "hyperparameters": {
# algo-1-qw37t_1  |         "exploration_policy": "cover",
# algo-1-qw37t_1  |         "epsilon": 0.1,
# algo-1-qw37t_1  |         "num_policies": 3,
# algo-1-qw37t_1  |         "num_arms": 2,
# algo-1-qw37t_1  |         "cfa_type": "dr"
# algo-1-qw37t_1  |     },
# algo-1-qw37t_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-qw37t_1  |     "input_data_config": {
# algo-1-qw37t_1  |         "training": {
# algo-1-qw37t_1  |             "TrainingInputMode": "File"
# algo-1-qw37t_1  |         },
# algo-1-qw37t_1  |         "pretrained_model": {
# algo-1-qw37t_1  |             "TrainingInputMode": "File",
# algo-1-qw37t_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-qw37t_1  |         }
# algo-1-qw37t_1  |     },
# algo-1-qw37t_1  |     "input_dir": "/opt/ml/input",
# algo-1-qw37t_1  |     "is_master": true,
# algo-1-qw37t_1  |     "job_name": "bandits-1601151981-model-id-1601152151",
# algo-1-qw37t_1  |     "log_level": 20,
# algo-1-qw37t_1  |     "master_hostname": "algo-1-qw37t",
# algo-1-qw37t_1  |     "model_dir": "/opt/ml/model",
# algo-1-qw37t_1  |     "module_dir": "s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152151/source/sourcedir.tar.gz",
# algo-1-qw37t_1  |     "module_name": "train-vw",
# algo-1-qw37t_1  |     "network_interface_name": "eth0",
# algo-1-qw37t_1  |     "num_cpus": 8,
# algo-1-qw37t_1  |     "num_gpus": 0,
# algo-1-qw37t_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-qw37t_1  |     "output_dir": "/opt/ml/output",
# algo-1-qw37t_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-qw37t_1  |     "resource_config": {
# algo-1-qw37t_1  |         "current_host": "algo-1-qw37t",
# algo-1-qw37t_1  |         "hosts": [
# algo-1-qw37t_1  |             "algo-1-qw37t"
# algo-1-qw37t_1  |         ]
# algo-1-qw37t_1  |     },
# algo-1-qw37t_1  |     "user_entry_point": "train-vw.py"
# algo-1-qw37t_1  | }
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | Environment variables:
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | SM_HOSTS=["algo-1-qw37t"]
# algo-1-qw37t_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-qw37t_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-qw37t_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-qw37t_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-qw37t_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-qw37t","hosts":["algo-1-qw37t"]}
# algo-1-qw37t_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-qw37t_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-qw37t_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-qw37t_1  | SM_CURRENT_HOST=algo-1-qw37t
# algo-1-qw37t_1  | SM_MODULE_NAME=train-vw
# algo-1-qw37t_1  | SM_LOG_LEVEL=20
# algo-1-qw37t_1  | SM_FRAMEWORK_MODULE=
# algo-1-qw37t_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-qw37t_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-qw37t_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-qw37t_1  | SM_NUM_CPUS=8
# algo-1-qw37t_1  | SM_NUM_GPUS=0
# algo-1-qw37t_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-qw37t_1  | SM_MODULE_DIR=s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152151/source/sourcedir.tar.gz
# algo-1-qw37t_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-qw37t","framework_module":null,"hosts":["algo-1-qw37t"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601151981-model-id-1601152151","log_level":20,"master_hostname":"algo-1-qw37t","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152151/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-qw37t","hosts":["algo-1-qw37t"]},"user_entry_point":"train-vw.py"}
# algo-1-qw37t_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-qw37t_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-qw37t_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-qw37t_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-qw37t_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-qw37t_1  | SM_HP_EPSILON=0.1
# algo-1-qw37t_1  | SM_HP_NUM_POLICIES=3
# algo-1-qw37t_1  | SM_HP_NUM_ARMS=2
# algo-1-qw37t_1  | SM_HP_CFA_TYPE=dr
# algo-1-qw37t_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | Invoking script with the following command:
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-qw37t_1  |
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-qw37t_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-qw37t_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-qw37t_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-qw37t_1  | INFO:VW CLI:successfully created VWModel
# algo-1-qw37t_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-qw37t_1  | INFO:VW CLI:Started VW process!
# algo-1-qw37t_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152143.csv')]
# algo-1-qw37t_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-qw37t_1  | predictions = /dev/stdout
# algo-1-qw37t_1  | Num weight bits = 18
# algo-1-qw37t_1  | learning rate = 0.5
# algo-1-qw37t_1  | initial_t = 0
# algo-1-qw37t_1  | power_t = 0.5
# algo-1-qw37t_1  | using no cache
# algo-1-qw37t_1  | Reading datafile =
# algo-1-qw37t_1  | num sources = 1
# algo-1-qw37t_1  | average  since         example        example  current  current  current
# algo-1-qw37t_1  | loss     last          counter         weight    label  predict features
# algo-1-qw37t_1  | 0.000000 0.000000            1            1.0        1 1:0.500000        2
# algo-1-qw37t_1  | 0.000000 0.000000            2            2.0        1 2:1.000000        2
# algo-1-qw37t_1  | 0.000000 0.000000            4            4.0        1 2:1.000000        2
# algo-1-qw37t_1  | 0.000000 0.000000            8            8.0        1 2:1.000000        2
# algo-1-qw37t_1  | 0.000000 0.000000           16           16.0        1 2:1.000000        1
# algo-1-qw37t_1  | 0.031250 0.062500           32           32.0        1 2:1.000000        2
# algo-1-qw37t_1  | 0.046875 0.062500           64           64.0        1 2:0.666667        2
# algo-1-qw37t_1  | 0.217643 0.388412          128          128.0        1 1:1.000000        2
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | finished run
# algo-1-qw37t_1  | number of examples = 175
# algo-1-qw37t_1  | weighted example sum = 175.000000
# algo-1-qw37t_1  | weighted label sum = 0.000000
# algo-1-qw37t_1  | average loss = 0.324406
# algo-1-qw37t_1  | total feature number = 347
# algo-1-qw37t_1  |
# algo-1-qw37t_1  | INFO:root:Model learned using 175 training experiences.
# algo-1-qw37t_1  | 2020-09-26 20:29:17,068 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpitv0x61h/algo-1-qw37t Please remove it manually.
# tmpitv0x61h_algo-1-qw37t_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
# INFO:orchestrator:Evaluating model 'bandits-1601151981-model-id-1601152151' with evaluation job id 'bandits-1601151981-model-id-1601152151-eval-1601152167'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmphpeik0_s/algo-1-7p5z4 Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601151981-model-id-1601152151' on eval data set 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152142/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601151981-model-id-1601152151'with data 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152142/eval' is 0.37485.
# INFO:orchestrator:Evaluating model 'bandits-1601151981-model-id-1601152109' with evaluation job id 'bandits-1601151981-model-id-1601152109-eval-1601152182'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmptd8wcwt0/algo-1-9una7 Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601151981-model-id-1601152109' on eval data set 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152142/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601151981-model-id-1601152109'with data 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152142/eval' is 0.461223.
# New bandit model evaluation score 0.461223
# Current bandit model evaluation score 0.37485
# Deploying new bandit model id bandits-1601151981-model-id-1601152151 in loop 0
# INFO:orchestrator:Model 'bandits-1601151981-model-id-1601152151' is ready to deploy.
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Found new model! Trying to replace Model ID: bandits-1601151981-model-id-1601152109 with Model ID: bandits-1601151981-model-id-1601152151
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [23] [INFO] Handling signal: hup
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [23] [INFO] Hang up: Master
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [52] [INFO] Booting worker with pid: 52
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [53] [INFO] Booting worker with pid: 53
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/BfevW2sY/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152151
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [54] [INFO] Booting worker with pid: 54
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [39] [INFO] Worker exiting (pid: 39)
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [38] [INFO] Worker exiting (pid: 38)
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [41] [INFO] Worker exiting (pid: 41)
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [40] [INFO] Worker exiting (pid: 40)
# algo-1-ko0fh_1  | [2020-09-26 20:29:58 +0000] [55] [INFO] Booting worker with pid: 55
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/BfevW2sY/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152151
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/BfevW2sY/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152151
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/BfevW2sY/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152151
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:29:58 INFO 139964419942144] Started VW process!
#
#     ################################
#     # Incremental Training Loop 2
#     ################################
#
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 2
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 2
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 3
# Predicted Class from Model 2: 3, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 2, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 2: 1, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 2, Actual Class: 2
# Predicted Class from Model 1: 2, Actual Class: 2
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 2
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 2: 3, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 2: 2, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 3
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 2: 2, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 2
# Predicted Class from Model 2: 2, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152219
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152219/train/local-joined-data-1601152220.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152219/eval/local-joined-data-1601152220.csv
# INFO:orchestrator:Use last trained model bandits-1601151981-model-id-1601152151 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601151981-model-id-1601152228''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmpkwk6c9qv_algo-1-ggzzx_1 ...
# Attaching to tmpkwk6c9qv_algo-1-ggzzx_12mdone
# algo-1-ggzzx_1  | 2020-09-26 20:30:33,483 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ggzzx_1  | 2020-09-26 20:30:33,495 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ggzzx_1  | 2020-09-26 20:30:33,506 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-ggzzx_1  | 2020-09-26 20:30:33,515 sagemaker-containers INFO     Invoking user script
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | Training Env:
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | {
# algo-1-ggzzx_1  |     "additional_framework_parameters": {
# algo-1-ggzzx_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-ggzzx_1  |     },
# algo-1-ggzzx_1  |     "channel_input_dirs": {
# algo-1-ggzzx_1  |         "training": "/opt/ml/input/data/training",
# algo-1-ggzzx_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-ggzzx_1  |     },
# algo-1-ggzzx_1  |     "current_host": "algo-1-ggzzx",
# algo-1-ggzzx_1  |     "framework_module": null,
# algo-1-ggzzx_1  |     "hosts": [
# algo-1-ggzzx_1  |         "algo-1-ggzzx"
# algo-1-ggzzx_1  |     ],
# algo-1-ggzzx_1  |     "hyperparameters": {
# algo-1-ggzzx_1  |         "exploration_policy": "cover",
# algo-1-ggzzx_1  |         "epsilon": 0.1,
# algo-1-ggzzx_1  |         "num_policies": 3,
# algo-1-ggzzx_1  |         "num_arms": 2,
# algo-1-ggzzx_1  |         "cfa_type": "dr"
# algo-1-ggzzx_1  |     },
# algo-1-ggzzx_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-ggzzx_1  |     "input_data_config": {
# algo-1-ggzzx_1  |         "training": {
# algo-1-ggzzx_1  |             "TrainingInputMode": "File"
# algo-1-ggzzx_1  |         },
# algo-1-ggzzx_1  |         "pretrained_model": {
# algo-1-ggzzx_1  |             "TrainingInputMode": "File",
# algo-1-ggzzx_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-ggzzx_1  |         }
# algo-1-ggzzx_1  |     },
# algo-1-ggzzx_1  |     "input_dir": "/opt/ml/input",
# algo-1-ggzzx_1  |     "is_master": true,
# algo-1-ggzzx_1  |     "job_name": "bandits-1601151981-model-id-1601152228",
# algo-1-ggzzx_1  |     "log_level": 20,
# algo-1-ggzzx_1  |     "master_hostname": "algo-1-ggzzx",
# algo-1-ggzzx_1  |     "model_dir": "/opt/ml/model",
# algo-1-ggzzx_1  |     "module_dir": "s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152228/source/sourcedir.tar.gz",
# algo-1-ggzzx_1  |     "module_name": "train-vw",
# algo-1-ggzzx_1  |     "network_interface_name": "eth0",
# algo-1-ggzzx_1  |     "num_cpus": 8,
# algo-1-ggzzx_1  |     "num_gpus": 0,
# algo-1-ggzzx_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-ggzzx_1  |     "output_dir": "/opt/ml/output",
# algo-1-ggzzx_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-ggzzx_1  |     "resource_config": {
# algo-1-ggzzx_1  |         "current_host": "algo-1-ggzzx",
# algo-1-ggzzx_1  |         "hosts": [
# algo-1-ggzzx_1  |             "algo-1-ggzzx"
# algo-1-ggzzx_1  |         ]
# algo-1-ggzzx_1  |     },
# algo-1-ggzzx_1  |     "user_entry_point": "train-vw.py"
# algo-1-ggzzx_1  | }
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | Environment variables:
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | SM_HOSTS=["algo-1-ggzzx"]
# algo-1-ggzzx_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-ggzzx_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-ggzzx_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-ggzzx_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-ggzzx_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-ggzzx","hosts":["algo-1-ggzzx"]}
# algo-1-ggzzx_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-ggzzx_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-ggzzx_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-ggzzx_1  | SM_CURRENT_HOST=algo-1-ggzzx
# algo-1-ggzzx_1  | SM_MODULE_NAME=train-vw
# algo-1-ggzzx_1  | SM_LOG_LEVEL=20
# algo-1-ggzzx_1  | SM_FRAMEWORK_MODULE=
# algo-1-ggzzx_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-ggzzx_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-ggzzx_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-ggzzx_1  | SM_NUM_CPUS=8
# algo-1-ggzzx_1  | SM_NUM_GPUS=0
# algo-1-ggzzx_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-ggzzx_1  | SM_MODULE_DIR=s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152228/source/sourcedir.tar.gz
# algo-1-ggzzx_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-ggzzx","framework_module":null,"hosts":["algo-1-ggzzx"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601151981-model-id-1601152228","log_level":20,"master_hostname":"algo-1-ggzzx","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152228/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ggzzx","hosts":["algo-1-ggzzx"]},"user_entry_point":"train-vw.py"}
# algo-1-ggzzx_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-ggzzx_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-ggzzx_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-ggzzx_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-ggzzx_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-ggzzx_1  | SM_HP_EPSILON=0.1
# algo-1-ggzzx_1  | SM_HP_NUM_POLICIES=3
# algo-1-ggzzx_1  | SM_HP_NUM_ARMS=2
# algo-1-ggzzx_1  | SM_HP_CFA_TYPE=dr
# algo-1-ggzzx_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | Invoking script with the following command:
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-ggzzx_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-ggzzx_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-ggzzx_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-ggzzx_1  | INFO:VW CLI:successfully created VWModel
# algo-1-ggzzx_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-ggzzx_1  | INFO:VW CLI:Started VW process!
# algo-1-ggzzx_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152220.csv')]
# algo-1-ggzzx_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-ggzzx_1  | predictions = /dev/stdout
# algo-1-ggzzx_1  | Num weight bits = 18
# algo-1-ggzzx_1  | learning rate = 0.5
# algo-1-ggzzx_1  | initial_t = 0
# algo-1-ggzzx_1  | power_t = 0.5
# algo-1-ggzzx_1  | using no cache
# algo-1-ggzzx_1  | Reading datafile =
# algo-1-ggzzx_1  | num sources = 1
# algo-1-ggzzx_1  | average  since         example        example  current  current  current
# algo-1-ggzzx_1  | loss     last          counter         weight    label  predict features
# algo-1-ggzzx_1  | 1.000000 1.000000            1            1.0        1 1:1.000000        2
# algo-1-ggzzx_1  | 1.064415 1.128830            2            2.0        1 1:0.500000        2
# algo-1-ggzzx_1  | 0.915919 0.767424            4            4.0        1 1:0.591752        2
# algo-1-ggzzx_1  | 0.666857 0.417795            8            8.0        1 2:0.666667        2
# algo-1-ggzzx_1  | 0.559307 0.451756           16           16.0        1 1:1.000000        2
# algo-1-ggzzx_1  | 0.511955 0.464603           32           32.0        1 1:0.666667        2
# algo-1-ggzzx_1  | 0.521650 0.531346           64           64.0        1 1:1.000000        2
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | finished run
# algo-1-ggzzx_1  | number of examples = 95
# algo-1-ggzzx_1  | weighted example sum = 95.000000
# algo-1-ggzzx_1  | weighted label sum = 0.000000
# algo-1-ggzzx_1  | average loss = 0.583140
# algo-1-ggzzx_1  | total feature number = 189
# algo-1-ggzzx_1  |
# algo-1-ggzzx_1  | INFO:root:Model learned using 95 training experiences.
# algo-1-ggzzx_1  | 2020-09-26 20:30:33,965 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpkwk6c9qv/algo-1-ggzzx Please remove it manually.
# tmpkwk6c9qv_algo-1-ggzzx_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
# INFO:orchestrator:Evaluating model 'bandits-1601151981-model-id-1601152228' with evaluation job id 'bandits-1601151981-model-id-1601152228-eval-1601152244'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpkcz9k09h/algo-1-kjuex Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601151981-model-id-1601152228' on eval data set 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152219/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601151981-model-id-1601152228'with data 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152219/eval' is 0.0.
# INFO:orchestrator:Evaluating model 'bandits-1601151981-model-id-1601152151' with evaluation job id 'bandits-1601151981-model-id-1601152151-eval-1601152259'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpszsl3phn/algo-1-2nad6 Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601151981-model-id-1601152151' on eval data set 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152219/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601151981-model-id-1601152151'with data 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152219/eval' is 0.2.
# New bandit model evaluation score 0.2
# Current bandit model evaluation score 0.0
# Deploying new bandit model id bandits-1601151981-model-id-1601152228 in loop 1
# INFO:orchestrator:Model 'bandits-1601151981-model-id-1601152228' is ready to deploy.
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Found new model! Trying to replace Model ID: bandits-1601151981-model-id-1601152151 with Model ID: bandits-1601151981-model-id-1601152228
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [23] [INFO] Handling signal: hup
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [23] [INFO] Hang up: Master
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [66] [INFO] Booting worker with pid: 66
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [67] [INFO] Booting worker with pid: 67
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/rGcIB5Kq/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152228
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [68] [INFO] Booting worker with pid: 68
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [52] [INFO] Worker exiting (pid: 52)
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [54] [INFO] Worker exiting (pid: 54)
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [53] [INFO] Worker exiting (pid: 53)
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/rGcIB5Kq/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152228
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [69] [INFO] Booting worker with pid: 69
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [2020-09-26 20:31:15 +0000] [55] [INFO] Worker exiting (pid: 55)
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/rGcIB5Kq/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152228
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/rGcIB5Kq/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152228
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:31:15 INFO 139964419942144] Started VW process!
#
#     ################################
#     # Incremental Training Loop 3
#     ################################
#
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 3
# Predicted Class from Model 2: 2, Actual Class: 2
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 3
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 2: 2, Actual Class: 3
# Predicted Class from Model 1: 3, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 3, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 2: 3, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 5
# Predicted Class from Model 1: 2, Actual Class: 2
# Predicted Class from Model 2: 1, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 4
# Predicted Class from Model 1: 4, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 4, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 3
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 2: 5, Actual Class: 4
# Predicted Class from Model 1: 2, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 2, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 2: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 2
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 1: 3, Actual Class: 3
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 2: 3, Actual Class: 4
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 4, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 2: 2, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 5, Actual Class: 5
# Predicted Class from Model 2: 1, Actual Class: 2
# Predicted Class from Model 2: 1, Actual Class: 1
# Predicted Class from Model 1: 1, Actual Class: 5
# Predicted Class from Model 1: 5, Actual Class: 4
# Predicted Class from Model 1: 1, Actual Class: 1
# Predicted Class from Model 1: 3, Actual Class: 5
# Predicted Class from Model 1: 1, Actual Class: 1
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152295
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152295/train/local-joined-data-1601152296.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152295/eval/local-joined-data-1601152296.csv
# INFO:orchestrator:Use last trained model bandits-1601151981-model-id-1601152228 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601151981-model-id-1601152304''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmp3ih3c5xr_algo-1-1qao9_1 ...
# Attaching to tmp3ih3c5xr_algo-1-1qao9_12mdone
# algo-1-1qao9_1  | 2020-09-26 20:31:49,375 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# ...
# Predicted Class from Model 1: 1, Actual Class: 2
# Predicted Class from Model 1: 1, Actual Class: 1
# INFO:orchestrator:Started dummy local joining job...
# INFO:orchestrator:Splitting data into train/evaluation set with ratio of 0.9
# INFO:orchestrator:Joined data will be stored under s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152448
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152448/train/local-joined-data-1601152448.csv
# INFO:orchestrator:_upload_data_buffer_as_joined_data_format put s3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152448/eval/local-joined-data-1601152448.csv
# INFO:orchestrator:Use last trained model bandits-1601151981-model-id-1601152380 as pre-trained model for training
# INFO:orchestrator:Starting training job for ModelId 'bandits-1601151981-model-id-1601152457''
# INFO:orchestrator:Training job will be executed in 'local' mode
# Creating tmp170286xa_algo-1-6psls_1 ...
# Attaching to tmp170286xa_algo-1-6psls_12mdone
# algo-1-6psls_1  | 2020-09-26 20:34:21,800 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-6psls_1  | 2020-09-26 20:34:21,812 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-6psls_1  | 2020-09-26 20:34:21,824 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-6psls_1  | 2020-09-26 20:34:21,833 sagemaker-containers INFO     Invoking user script
# algo-1-6psls_1  |
# algo-1-6psls_1  | Training Env:
# algo-1-6psls_1  |
# algo-1-6psls_1  | {
# algo-1-6psls_1  |     "additional_framework_parameters": {
# algo-1-6psls_1  |         "sagemaker_estimator": "RLEstimator"
# algo-1-6psls_1  |     },
# algo-1-6psls_1  |     "channel_input_dirs": {
# algo-1-6psls_1  |         "training": "/opt/ml/input/data/training",
# algo-1-6psls_1  |         "pretrained_model": "/opt/ml/input/data/pretrained_model"
# algo-1-6psls_1  |     },
# algo-1-6psls_1  |     "current_host": "algo-1-6psls",
# algo-1-6psls_1  |     "framework_module": null,
# algo-1-6psls_1  |     "hosts": [
# algo-1-6psls_1  |         "algo-1-6psls"
# algo-1-6psls_1  |     ],
# algo-1-6psls_1  |     "hyperparameters": {
# algo-1-6psls_1  |         "exploration_policy": "cover",
# algo-1-6psls_1  |         "epsilon": 0.1,
# algo-1-6psls_1  |         "num_policies": 3,
# algo-1-6psls_1  |         "num_arms": 2,
# algo-1-6psls_1  |         "cfa_type": "dr"
# algo-1-6psls_1  |     },
# algo-1-6psls_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-6psls_1  |     "input_data_config": {
# algo-1-6psls_1  |         "training": {
# algo-1-6psls_1  |             "TrainingInputMode": "File"
# algo-1-6psls_1  |         },
# algo-1-6psls_1  |         "pretrained_model": {
# algo-1-6psls_1  |             "TrainingInputMode": "File",
# algo-1-6psls_1  |             "ContentType": "application/x-sagemaker-model"
# algo-1-6psls_1  |         }
# algo-1-6psls_1  |     },
# algo-1-6psls_1  |     "input_dir": "/opt/ml/input",
# algo-1-6psls_1  |     "is_master": true,
# algo-1-6psls_1  |     "job_name": "bandits-1601151981-model-id-1601152457",
# algo-1-6psls_1  |     "log_level": 20,
# algo-1-6psls_1  |     "master_hostname": "algo-1-6psls",
# algo-1-6psls_1  |     "model_dir": "/opt/ml/model",
# algo-1-6psls_1  |     "module_dir": "s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152457/source/sourcedir.tar.gz",
# algo-1-6psls_1  |     "module_name": "train-vw",
# algo-1-6psls_1  |     "network_interface_name": "eth0",
# algo-1-6psls_1  |     "num_cpus": 8,
# algo-1-6psls_1  |     "num_gpus": 0,
# algo-1-6psls_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-6psls_1  |     "output_dir": "/opt/ml/output",
# algo-1-6psls_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-6psls_1  |     "resource_config": {
# algo-1-6psls_1  |         "current_host": "algo-1-6psls",
# algo-1-6psls_1  |         "hosts": [
# algo-1-6psls_1  |             "algo-1-6psls"
# algo-1-6psls_1  |         ]
# algo-1-6psls_1  |     },
# algo-1-6psls_1  |     "user_entry_point": "train-vw.py"
# algo-1-6psls_1  | }
# algo-1-6psls_1  |
# algo-1-6psls_1  | Environment variables:
# algo-1-6psls_1  |
# algo-1-6psls_1  | SM_HOSTS=["algo-1-6psls"]
# algo-1-6psls_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-6psls_1  | SM_HPS={"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3}
# algo-1-6psls_1  | SM_USER_ENTRY_POINT=train-vw.py
# algo-1-6psls_1  | SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# algo-1-6psls_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-6psls","hosts":["algo-1-6psls"]}
# algo-1-6psls_1  | SM_INPUT_DATA_CONFIG={"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-6psls_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-6psls_1  | SM_CHANNELS=["pretrained_model","training"]
# algo-1-6psls_1  | SM_CURRENT_HOST=algo-1-6psls
# algo-1-6psls_1  | SM_MODULE_NAME=train-vw
# algo-1-6psls_1  | SM_LOG_LEVEL=20
# algo-1-6psls_1  | SM_FRAMEWORK_MODULE=
# algo-1-6psls_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-6psls_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-6psls_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-6psls_1  | SM_NUM_CPUS=8
# algo-1-6psls_1  | SM_NUM_GPUS=0
# algo-1-6psls_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-6psls_1  | SM_MODULE_DIR=s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152457/source/sourcedir.tar.gz
# algo-1-6psls_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{"pretrained_model":"/opt/ml/input/data/pretrained_model","training":"/opt/ml/input/data/training"},"current_host":"algo-1-6psls","framework_module":null,"hosts":["algo-1-6psls"],"hyperparameters":{"cfa_type":"dr","epsilon":0.1,"exploration_policy":"cover","num_arms":2,"num_policies":3},"input_config_dir":"/opt/ml/input/config","input_data_config":{"pretrained_model":{"ContentType":"application/x-sagemaker-model","TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"bandits-1601151981-model-id-1601152457","log_level":20,"master_hostname":"algo-1-6psls","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-354474215062/bandits-1601151981/training_jobs/bandits-1601151981-model-id-1601152457/source/sourcedir.tar.gz","module_name":"train-vw","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-6psls","hosts":["algo-1-6psls"]},"user_entry_point":"train-vw.py"}
# algo-1-6psls_1  | SM_USER_ARGS=["--cfa_type","dr","--epsilon","0.1","--exploration_policy","cover","--num_arms","2","--num_policies","3"]
# algo-1-6psls_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-6psls_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-6psls_1  | SM_CHANNEL_PRETRAINED_MODEL=/opt/ml/input/data/pretrained_model
# algo-1-6psls_1  | SM_HP_EXPLORATION_POLICY=cover
# algo-1-6psls_1  | SM_HP_EPSILON=0.1
# algo-1-6psls_1  | SM_HP_NUM_POLICIES=3
# algo-1-6psls_1  | SM_HP_NUM_ARMS=2
# algo-1-6psls_1  | SM_HP_CFA_TYPE=dr
# algo-1-6psls_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/vowpal_wabbit/python:/vowpal_wabbit/build/python:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-6psls_1  |
# algo-1-6psls_1  | Invoking script with the following command:
# algo-1-6psls_1  |
# algo-1-6psls_1  | /usr/bin/python train-vw.py --cfa_type dr --epsilon 0.1 --exploration_policy cover --num_arms 2 --num_policies 3
# algo-1-6psls_1  |
# algo-1-6psls_1  |
# algo-1-6psls_1  | INFO:root:channels ['pretrained_model', 'training']
# algo-1-6psls_1  | INFO:root:hps: {'cfa_type': 'dr', 'epsilon': 0.1, 'exploration_policy': 'cover', 'num_arms': 2, 'num_policies': 3}
# algo-1-6psls_1  | INFO:root:Loading model from /opt/ml/input/data/pretrained_model/vw.model
# algo-1-6psls_1  | INFO:VW CLI:creating an instance of VWModel
# algo-1-6psls_1  | INFO:VW CLI:successfully created VWModel
# algo-1-6psls_1  | INFO:VW CLI:command: ['vw', '--cb_explore', '2', '--cover', '3', '-i', '/opt/ml/input/data/pretrained_model/vw.model', '-f', '/opt/ml/model/vw.model', '--save_resume', '-p', '/dev/stdout']
# algo-1-6psls_1  | INFO:VW CLI:Started VW process!
# algo-1-6psls_1  | INFO:root:Processing training data: [PosixPath('/opt/ml/input/data/training/local-joined-data-1601152448.csv')]
# algo-1-6psls_1  | final_regressor = /opt/ml/model/vw.model
# algo-1-6psls_1  | predictions = /dev/stdout
# algo-1-6psls_1  | Num weight bits = 18
# algo-1-6psls_1  | learning rate = 0.5
# algo-1-6psls_1  | initial_t = 0
# algo-1-6psls_1  | power_t = 0.5
# algo-1-6psls_1  | using no cache
# algo-1-6psls_1  | Reading datafile =
# algo-1-6psls_1  | num sources = 1
# algo-1-6psls_1  | average  since         example        example  current  current  current
# algo-1-6psls_1  | loss     last          counter         weight    label  predict features
# algo-1-6psls_1  | 0.203380 0.203380            1            1.0        1 1:0.500000        2
# algo-1-6psls_1  | 0.686119 1.168857            2            2.0        1 1:0.500000        2
# algo-1-6psls_1  | 0.513670 0.341221            4            4.0        2 1:1.000000        2
# algo-1-6psls_1  | 0.583674 0.653677            8            8.0        1 1:1.000000        2
# algo-1-6psls_1  | 0.530552 0.477430           16           16.0        1 1:0.666667        2
# algo-1-6psls_1  | 0.610590 0.690629           32           32.0        1 2:0.666667        2
# algo-1-6psls_1  | 0.625110 0.639630           64           64.0        1 1:0.666667        2
# algo-1-6psls_1  |
# algo-1-6psls_1  | finished run
# algo-1-6psls_1  | number of examples = 92
# algo-1-6psls_1  | weighted example sum = 92.000000
# algo-1-6psls_1  | weighted label sum = 0.000000
# algo-1-6psls_1  | average loss = 0.604401
# algo-1-6psls_1  | total feature number = 183
# algo-1-6psls_1  |
# algo-1-6psls_1  | INFO:root:Model learned using 92 training experiences.
# algo-1-6psls_1  | 2020-09-26 20:34:22,292 sagemaker-containers INFO     Reporting training SUCCESS
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmp170286xa/algo-1-6psls Please remove it manually.
# tmp170286xa_algo-1-6psls_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
# INFO:orchestrator:Evaluating model 'bandits-1601151981-model-id-1601152457' with evaluation job id 'bandits-1601151981-model-id-1601152457-eval-1601152472'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmpg8o2reuo/algo-1-5vpfz Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601151981-model-id-1601152457' on eval data set 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152448/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601151981-model-id-1601152457'with data 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152448/eval' is 0.59752.
# INFO:orchestrator:Evaluating model 'bandits-1601151981-model-id-1601152380' with evaluation job id 'bandits-1601151981-model-id-1601152380-eval-1601152487'
# INFO:orchestrator:Evaluation job will be executed in 'local' mode
# WARNING:sagemaker.local.image:Failed to delete: /tmp/tmp4bi924_r/algo-1-yc2nn Please remove it manually.
# INFO:orchestrator:Getting eval scores for model 'bandits-1601151981-model-id-1601152380' on eval data set 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152448/eval'
# INFO:orchestrator:Evaluation score for model 'bandits-1601151981-model-id-1601152380'with data 's3://sagemaker-us-west-2-354474215062/bandits-1601151981/joined_data/bandits-1601151981-join-job-id-1601152448/eval' is 0.683757.
# New bandit model evaluation score 0.683757
# Current bandit model evaluation score 0.59752
# Deploying new bandit model id bandits-1601151981-model-id-1601152457 in loop 4
# INFO:orchestrator:Model 'bandits-1601151981-model-id-1601152457' is ready to deploy.
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Found new model! Trying to replace Model ID: bandits-1601151981-model-id-1601152380 with Model ID: bandits-1601151981-model-id-1601152457
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [23] [INFO] Handling signal: hup
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [23] [INFO] Hang up: Master
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [108] [INFO] Booting worker with pid: 108
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [109] [INFO] Booting worker with pid: 109
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Dx8qHFym/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152457
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [110] [INFO] Booting worker with pid: 110
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Dx8qHFym/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152457
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [95] [INFO] Worker exiting (pid: 95)
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [96] [INFO] Worker exiting (pid: 96)
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [94] [INFO] Worker exiting (pid: 94)
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [112] [INFO] Booting worker with pid: 112
# algo-1-ko0fh_1  | [2020-09-26 20:35:03 +0000] [97] [INFO] Worker exiting (pid: 97)
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] creating an instance of VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Dx8qHFym/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] successfully created VWModel
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] command: ['vw', '--cb_explore', '2', '--cover', '3', '-p', '/dev/stdout', '--quiet', '--testonly', '-i', '/opt/ml/downloads/Dx8qHFym/vw.model']
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152457
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Loaded weights successfully for Model ID:bandits-1601151981-model-id-1601152457
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Started VW process!
# algo-1-ko0fh_1  | [09/26/2020 20:35:03 INFO 139964419942144] Started VW process!
# Total time taken to complete 5 loops: 378.8177056312561

# %% [markdown]
# # _Ignore Any Errors ^^ Above ^^_

# %% [markdown]
# # Check Experiment State:  EVALUATED
#
# `evaluation_state`: `EVALUATED`
#
# The same bandit_model_id will appear in both `last_trained_model_id` and `last_evaluation_job_id` fields below.

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601151981',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601151981-model-id-1601152457',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601151981-model-id-1601152457',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601151981-join-job-id-1601152448',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': 'EVALUATED',
#   'last_evaluation_job_id': 'bandits-1601151981-model-id-1601152380-eval-1601152487',
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Check Experiment Status:  JOINED
# `joining_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601151981',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601151981-model-id-1601152457',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601151981-model-id-1601152457',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601151981-join-job-id-1601152448',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': 'EVALUATED',
#   'last_evaluation_job_id': 'bandits-1601151981-model-id-1601152380-eval-1601152487',
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Check Experiment Status:  DEPLOYED
# `deploying_state`:  `SUCCEEDED`

# %%
bandit_experiment_manager._jsonify()
# Out:
# {'experiment_id': 'bandits-1601151981',
#  'training_workflow_metadata': {'next_model_to_train_id': None,
#   'last_trained_model_id': 'bandits-1601151981-model-id-1601152457',
#   'training_state': 'TRAINED'},
#  'hosting_workflow_metadata': {'hosting_endpoint': 'local:arn-does-not-matter',
#   'hosting_state': <HostingState.DEPLOYED: 'DEPLOYED'>,
#   'last_hosted_model_id': 'bandits-1601151981-model-id-1601152457',
#   'next_model_to_host_id': None},
#  'joining_workflow_metadata': {'joining_state': 'SUCCEEDED',
#   'last_joined_job_id': 'bandits-1601151981-join-job-id-1601152448',
#   'next_join_job_id': None},
#  'evaluation_workflow_metadata': {'evaluation_state': 'EVALUATED',
#   'last_evaluation_job_id': 'bandits-1601151981-model-id-1601152380-eval-1601152487',
#   'next_evaluation_job_id': None}}

# %% [markdown]
# # Copy All Joined Event and Reward Data from S3 to Local Notebook

# %%
from sagemaker.s3 import S3Downloader

all_joined_data_s3_uri_list = all_joined_train_data_s3_uri_list + all_joined_eval_data_s3_uri_list

df_list = []

for joined_data_s3_prefix_uri in all_joined_data_s3_uri_list:
    joined_data_s3_uri_file_path = './'

    joined_data_s3_uri = S3Downloader.list(joined_data_s3_prefix_uri)[0]    
    S3Downloader.download(joined_data_s3_uri, joined_data_s3_uri_file_path)
    joined_data_local_file_path = joined_data_s3_uri.split('/')[-1]

    df = pd.read_csv(joined_data_local_file_path, 
                     delimiter=',', 
                     quoting=csv.QUOTE_ALL)
    
    df_list.append(df)

# %%
all_joined_data_df = pd.concat(df_list, ignore_index=True)
all_joined_data_df.tail(10)
# Out:
#      reward                                 event_id  action  action_prob  \
# 590       0  151861704271539846952721370032192487426       2     0.333333
# 591       1  152275957434343554614948330531923820546       2     0.333333
# 592       0  201759625583753906193207110351432318978       1     1.000000
# 593       1  202435061514820512524082109234973638658       1     0.591752
# 594       1  204755852465269600633040995400190918658       1     0.666667
# 595       0  206677548977248835279504156497122820098       1     0.666667
# 596       0  210823509600159529222644422908121841666       1     1.000000
# 597       0  212121256602482052218062785653911977986       2     0.333333
# 598       0  212530702992666019458885965176611405826       1     1.000000
# 599       0  212834056534990385610524381866294902786       2     0.333333
#
#                                    model_id observation  sample_prob
# 590  bandits-1601151981-model-id-1601152304        [20]     0.982239
# 591  bandits-1601151981-model-id-1601152304        [50]     0.969094
# 592  bandits-1601151981-model-id-1601152380        [17]     0.917828
# 593  bandits-1601151981-model-id-1601152380        [87]     0.996179
# 594  bandits-1601151981-model-id-1601152380        [29]     0.938517
# 595  bandits-1601151981-model-id-1601152380        [23]     0.914579
# 596  bandits-1601151981-model-id-1601152380         [6]     0.964924
# 597  bandits-1601151981-model-id-1601152380        [74]     0.900424
# 598  bandits-1601151981-model-id-1601152380         [9]     0.981704
# 599  bandits-1601151981-model-id-1601152380        [93]     0.954655

# %% [markdown]
# # Review Invocations of BERT Model 1 and 2

# %%
print('Total Invocations of BERT Model 1:  {}'.format(client_app.action_count[1]))
print('Total Invocations of BERT Model 2:  {}'.format(client_app.action_count[2]))
# Out:
# Total Invocations of BERT Model 1:  453
# Total Invocations of BERT Model 2:  147

# %%
from datetime import datetime, timedelta

import boto3
import pandas as pd

cw = boto3.Session().client(service_name='cloudwatch', region_name=region)

def get_invocation_metrics_for_endpoint_variant(endpoint_name,
                                                namespace_name,
                                                metric_name,
                                                variant_name,
                                                start_time,
                                                end_time):
    metrics = cw.get_metric_statistics(
        Namespace=namespace_name,
        MetricName=metric_name,
        StartTime=start_time,
        EndTime=end_time,
        Period=60,
        Statistics=["Sum"],
        Dimensions=[
            {
                "Name": "EndpointName",
                "Value": endpoint_name
            },
            {
                "Name": "VariantName",
                "Value": variant_name
            }
        ]
    )

    if metrics['Datapoints']:
        return pd.DataFrame(metrics["Datapoints"])\
                .sort_values("Timestamp")\
                .set_index("Timestamp")\
                .drop("Unit", axis=1)\
                .rename(columns={"Sum": variant_name})
    else:
        return pd.DataFrame()

# %% [markdown]
# # Gather BERT Model 1 Invocations Metrics
# _Please be patient.  This will take 1-2 minutes._

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

time.sleep(75)

start_time = start_time or datetime.now() - timedelta(minutes=60)
end_time = datetime.now()
        
model_1_endpoint_invocations = get_invocation_metrics_for_endpoint_variant(
                                    endpoint_name=model_1_endpoint_name,
                                    namespace_name='AWS/SageMaker',                                   
                                    metric_name='Invocations',
                                    variant_name='AllTraffic',
                                    start_time=start_time, 
                                    end_time=end_time)

model_1_endpoint_invocations
# Out:
#                            AllTraffic
# Timestamp
# 2020-09-26 20:28:00+00:00       128.0
# 2020-09-26 20:29:00+00:00         7.0
# 2020-09-26 20:30:00+00:00        89.0
# 2020-09-26 20:31:00+00:00        77.0
# 2020-09-26 20:32:00+00:00        74.0
# 2020-09-26 20:33:00+00:00        37.0
# 2020-09-26 20:34:00+00:00        41.0

# %% [markdown]
# # Gather BERT Model 2 Invocations Metrics
# _Please be patient.  This will take 1-2 minutes._

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

time.sleep(75)

start_time = start_time or datetime.now() - timedelta(minutes=60)
end_time = datetime.now()
        
model_2_endpoint_invocations = get_invocation_metrics_for_endpoint_variant(
                                    endpoint_name=model_2_endpoint_name,
                                    namespace_name='AWS/SageMaker',                                   
                                    metric_name='Invocations',
                                    variant_name='AllTraffic',
                                    start_time=start_time, 
                                    end_time=end_time)

model_2_endpoint_invocations
# Out:
#                            AllTraffic
# Timestamp
# 2020-09-26 20:28:00+00:00        48.0
# 2020-09-26 20:29:00+00:00        17.0
# 2020-09-26 20:30:00+00:00        11.0
# 2020-09-26 20:31:00+00:00        23.0
# 2020-09-26 20:32:00+00:00        26.0
# 2020-09-26 20:33:00+00:00        10.0
# 2020-09-26 20:34:00+00:00        12.0

# %%
rcParams['figure.figsize'] = 15, 10

x1 = range(0, model_1_endpoint_invocations.size)
y1 = model_1_endpoint_invocations['AllTraffic']
plt.plot(x1, y1, label="BERT Model 1")

x1 = range(0, model_2_endpoint_invocations.size)
y1 = model_2_endpoint_invocations['AllTraffic']
plt.plot(x1, y1, label="BERT Model 2")

plt.legend(loc=0, prop={'size': 20})
plt.xlabel('Time (Minutes)')
plt.ylabel('Number of Invocations')
# Out:
# Text(0, 0.5, 'Number of Invocations')

# %% [markdown]
# # Check the Invocation Metrics for the BERT Models

# %%
from IPython.core.display import display, HTML
    
display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region={}#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search={}">Model 1 SageMaker REST Endpoint</a></b>'.format(region, model_1_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search=tensorflow-training-2020-09-26-18-45-05-088-tf-1601151470">Model 1 SageMaker REST Endpoint</a></b>

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region={}#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search={}">Model 2 SageMaker REST Endpoint</a></b>'.format(region, model_2_endpoint_name)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#metricsV2:namespace=AWS/SageMaker;dimensions=EndpointName,VariantName;search=tensorflow-training-2020-09-26-18-45-05-088-pt-1601151131">Model 2 SageMaker REST Endpoint</a></b>

# %% [markdown]
# # Visualize Bandit Action Probabilities
# This is the probability that the bandit model will choose a particular BERT model (action).

# %%
rcParams['figure.figsize'] = 15, 10

x1 = all_joined_data_df.query('action==1').index
y1 = all_joined_data_df.query('action==1').action_prob
plt.scatter(x1, y1, label="BERT Model 1")

x2 = all_joined_data_df.query('action==2').index
y2 = all_joined_data_df.query('action==2').action_prob
plt.scatter(x2, y2, label="BERT Model 2")

plt.legend(loc=3, prop={'size': 20})
plt.xlabel('Bandit Model Training Instances')
plt.ylabel('Action Probability')
# Out:
# Text(0, 0.5, 'Action Probability')

# %%
print('Mean action probability for BERT Model 1: {}'.format(all_joined_data_df.query('action==1')['action_prob'].mean()))
# Out:
# Mean action probability for BERT Model 1: 0.7570164547461365

# %%
print('Mean action probability for BERT Model 2: {}'.format(all_joined_data_df.query('action==2')['action_prob'].mean()))
# Out:
# Mean action probability for BERT Model 2: 0.4965986326530625

# %% [markdown]
# # Visualize Bandit Sample Probabilities
# Despite the action probability, we sample from all actions (BERT models).  Below is the sample probability for the chosen BERT model.

# %%
rcParams['figure.figsize'] = 15, 10

x1 = all_joined_data_df.query('action==1').index
y1 = all_joined_data_df.query('action==1').sample_prob
plt.scatter(x1, y1, label="BERT Model 1")

x2 = all_joined_data_df.query('action==2').index
y2 = all_joined_data_df.query('action==2').sample_prob
plt.scatter(x2, y2, label="BERT Model 2")

plt.legend(loc=0, prop={'size': 20})
plt.xlabel('Bandit Model Training Instances')
plt.ylabel('Sample Probability')
# Out:
# Text(0, 0.5, 'Sample Probability')

# %%
print('Mean sample probability for BERT Model 1: {}'.format(all_joined_data_df.query('action==1')['sample_prob'].mean()))
# Out:
# Mean sample probability for BERT Model 1: 0.48255134714180636

# %%
print('Mean sample probability for BERT Model 2: {}'.format(all_joined_data_df.query('action==2')['sample_prob'].mean()))
# Out:
# Mean sample probability for BERT Model 2: 0.5416319101841692

# %% [markdown]
# # Visualize Bandit Rewards

# %% [markdown]
# You can visualize the bandit-model training performance by plotting the rolling mean reward across client interactions.
#
# Here rolling mean reward is calculated on the last `rolling_window` number of data instances, where each data instance corresponds to a single client interaction.

# %%
rolling_window = 100

rcParams['figure.figsize'] = 15, 10
lwd = 5
cmap = plt.get_cmap('tab20')
colors=plt.cm.tab20(np.linspace(0, 1, 20))

rewards_df = pd.DataFrame(rewards_list, columns=['bandit']).rolling(rolling_window).mean()
rewards_df['perfect'] = sum(client_app.optimal_rewards) / len(client_app.optimal_rewards)

rewards_df.tail(10)
# Out:
#      bandit  perfect
# 490    0.44      1.0
# 491    0.43      1.0
# 492    0.42      1.0
# 493    0.42      1.0
# 494    0.42      1.0
# 495    0.43      1.0
# 496    0.43      1.0
# 497    0.42      1.0
# 498    0.41      1.0
# 499    0.42      1.0

# %%
rewards_df.plot(y=['bandit', 'perfect'], 
                linewidth=lwd)
plt.legend(loc=4, prop={'size': 20})
plt.tick_params(axis='both', which='major', labelsize=15)
plt.yticks([0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 1.00])
plt.xticks([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])

plt.xlabel('Training Instances (Model is Updated Every %s Instances)' % retrain_batch_size, size=20)
plt.ylabel('Rolling {} Mean Reward'.format(rolling_window), size=30)
plt.grid()
plt.show()

# %%
rewards_df['bandit'].mean()
# Out:
# 0.46354114713216876

# %% [markdown]
# # Monitor the Bandit Model in CloudWatch

# %%
from markdown_helper import *
from IPython.display import Markdown

display(Markdown(bandit_experiment_manager.get_cloudwatch_dashboard_details()))
# Out:
# You can monitor your Training/Hosting evaluation metrics on this [CloudWatch Dashboard](https://us-west-2.console.aws.amazon.com/cloudwatch/home?region=us-west-2#dashboards:name=bandits-1601151981;start=PT1H)
#
# (Note: This would need Trained/Hosted Models to be evaluated in order to publish Evaluation Scores)

# %% [markdown]
# # Review the DynamoDB Tables and S3 Data

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://console.aws.amazon.com/dynamodb/home?region={}#tables:selected=BanditsExperimentTable;tab=items">Bandits Experiment DynamoDB Table</a></b>'.format(region)))
# Out:
# <b>Review <a target="blank" href="https://console.aws.amazon.com/dynamodb/home?region=us-west-2#tables:selected=BanditsExperimentTable;tab=items">Bandits Experiment DynamoDB Table</a></b>

# %%
from IPython.core.display import display, HTML

display(HTML('<b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/{}/{}/?region={}&tab=overview">Bandits Experiment S3 Data</a></b>'.format(bucket, bandit_experiment_manager.experiment_id, region)))
# Out:
# <b>Review <a target="blank" href="https://s3.console.aws.amazon.com/s3/buckets/sagemaker-us-west-2-354474215062/bandits-1601151981/?region=us-west-2&tab=overview">Bandits Experiment S3 Data</a></b>

# %% [markdown]
# # Clean Up

# %% [markdown]
# We have three DynamoDB tables from the bandits application above.  To better maintain them, we should remove the related records if the experiment has finished.
#
# Only execute the clean up cells below when you've finished the current experiment and want to deprecate everything associated with it.
#
# _The CloudWatch metrics will be removed during this cleanup step._

# %%
print('Cleaning up experiment_id {}'.format(bandit_experiment_manager.experiment_id))
try:
    bandit_experiment_manager.clean_resource(experiment_id=bandit_experiment_manager.experiment_id)
    bandit_experiment_manager.clean_table_records(experiment_id=bandit_experiment_manager.experiment_id)
except:
    print('Ignore any errors.  Errors are OK.')
# Out:
# INFO:orchestrator:Deleting hosting endpoint 'bandits-1601151981'...
# Cleaning up experiment_id bandits-1601151981
# WARNING:orchestrator.clients.ddb.join_db_client:Deleting join job records of experiment...
# WARNING:orchestrator.clients.ddb.model_db_client:Deleting model records of experiment...
# WARNING:orchestrator.clients.ddb.experiment_db_client:Deleting experiment record...
# Gracefully stopping... (press Ctrl+C again to force)
